# %% [markdown]
# # Imports

# %%
import os
import math
import copy
import random
import time
from datetime import datetime
from functools import partial
from pathlib import Path
from typing import Optional, Any

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.utils.checkpoint as checkpoint
from torch import nn
from torch.utils.data import Dataset, DataLoader, Subset
from torchvision.transforms import v2

from einops import rearrange
from timm.models.layers import DropPath, trunc_normal_
from timm.models.registry import register_model
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, ConfusionMatrixDisplay
)
from sklearn.model_selection import train_test_split

import wandb

print('✅ All imports successful')
# Out:
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.12/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# ✅ All imports successful

# %%
from kaggle_secrets import UserSecretsClient
wandb_key = UserSecretsClient().get_secret("WANDB_API_KEY")

wandb.login(key=wandb_key)
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: davian-yang to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# # Config

# %%
CONFIG = {
    "model": "Swin",
    "variant": "tiny",
    "exp_no": 5,
    
    "seed": 42,
    
    "num_classes": 4,
    "input_dim": 224,

    "epochs": 100,
    "batch_size": 64,
    "lr": 3e-4,
    "weight_decay": 0.05,
    "warmup_epochs": 10,
    "patience": 10,
    "delta": 1e-3,
    "max_saved_models": 5,

    "class_weights": [0.613, 0.839, 1.364, 2.26],

    "mean":  [0.1438080370426178, 0.1438080370426178, 0.1438080370426178],
    "std": [0.233843594789505, 0.233843594789505, 0.233843594789505],

    "csv_dir": "/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/kidneyData.csv",
    "root_dir": "/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone",
    "output_dir": "/kaggle/working/",

    "use_wandb": True,
    "wandb_project": "kidney-stone-ct",
}

CONFIG["root_dir"] = Path(CONFIG["root_dir"])
CONFIG["output_dir"] = Path(CONFIG["output_dir"])
CONFIG["output_dir"].mkdir(parents=True, exist_ok=True)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
CONFIG["device"] = device

def set_seed(seed: int):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(CONFIG["seed"])
print(f"✅ Device: {device}")
print(f"✅ Model: {CONFIG["model"]}-{CONFIG['variant']}, Experiment: {CONFIG["exp_no"]}, epochs: {CONFIG['epochs']}, lr: {CONFIG['lr']}")
# Out:
# ✅ Device: cuda
# ✅ Model: Swin-tiny, Experiment: 5, epochs: 100, lr: 0.0003

# %% [markdown]
# # Utility classes & functions

# %%
# Define color codes for terminal
class Colors:
    RESET = '\033[0m'
    GREEN = '\033[92m'
    RED = '\033[91m'
    YELLOW = '\033[93m'
    CYAN = '\033[96m'

def display_progress_bar(batch_idx, num_batches, loss, accuracy):
    """
    Function to display a colored progress bar.
    Args:
        batch_idx: Current batch index
        num_batches: Total number of batches
        loss: Current loss value
        accuracy: Current accuracy value
    """
    progress = (batch_idx + 1) / num_batches
    bar_length = 40  # Length of the progress bar (number of '==' chars)
    filled_length = int(bar_length * progress)
    bar = f"{Colors.GREEN}{'=' * filled_length}{Colors.RED}{'-' * (bar_length - filled_length)}{Colors.RESET}"

    print(f'\r[{bar}] {batch_idx + 1}/{num_batches} | {Colors.YELLOW}Loss:{Colors.RESET} {loss:.3f} | {Colors.YELLOW}Accuracy:{Colors.RESET} {accuracy:.2f}%', end='', flush=True)

# %%
import matplotlib.pyplot as plt

def plot_result(history, title="Training Progress", save_path=None):
    epochs = range(1, len(history['train_loss']) + 1)

    plt.figure(figsize=(12, 5))

    # Loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, history['train_loss'], label='Train', color='tomato')
    plt.plot(epochs, history['val_loss'], label='Validation', color='steelblue')
    plt.title("Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend(frameon=False)
    plt.grid(True, linestyle="--", alpha=0.3)

    # Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, history['train_acc'], label='Train', color='mediumseagreen')
    plt.plot(epochs, history['val_acc'], label='Validation', color='black')
    plt.title("Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend(frameon=False)
    plt.grid(True, linestyle="--", alpha=0.3)

    plt.suptitle(title, fontsize=14)
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    if save_path:
        plt.savefig(save_path, dpi=150, bbox_inches='tight')
        print(f'Plot saved to {save_path}')
    plt.show()

# %%
class EarlyStopping:
    def __init__(self, patience=5, delta=0.0):
        self.patience = patience
        self.delta = delta
        self.best_loss = float("inf")
        self.counter = 0
        self.best_model_state = None
        self.early_stop = False

    def __call__(self, val_loss, model):
        if self.best_loss - val_loss > self.delta:
            self.best_loss = val_loss
            self.best_model_state = copy.deepcopy(
                model.state_dict()
            )
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

    def load_best_model(self, model):
        if self.best_model_state is not None:
            model.load_state_dict(self.best_model_state)

# %%
import os
from typing import Optional, Any
from datetime import datetime
import time

import torch
import torch.nn as nn
import torch.optim as optim

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score


class Trainer:
    def __init__(
        self,
        model: nn.Module,
        device: torch.device,
        optimizer: optim.Optimizer,
        criterion: nn.Module,
        scheduler: Optional[Any] = None,
    ):
        self.model = model.to(device)
        self.device = device
        self.optimizer = optimizer
        self.criterion = criterion
        self.scheduler = scheduler
        self.history = {
            "train_loss": [],
            "train_acc": [],
            "val_loss": [],
            "val_acc": [],
        }

    def _run_epoch(self, loader, training=True, show_progress=True):
        self.model.train() if training else self.model.eval()

        running_loss = 0.0
        correct = 0
        total = 0
        all_preds, all_targets = [], []
        num_batches = len(loader)

        with torch.set_grad_enabled(training):
            for batch_idx, (inputs, targets) in enumerate(loader):
                inputs = inputs.to(self.device, non_blocking=True)
                targets = targets.to(self.device, non_blocking=True)

                outputs = self.model(inputs)
                loss = self.criterion(outputs, targets)

                if training:
                    loss.backward()
                    self.optimizer.step()
                    self.optimizer.zero_grad()

                running_loss += loss.item()
                _, preds = outputs.max(1)
                total += targets.size(0)
                correct += preds.eq(targets).sum().item()

                all_preds.extend(preds.cpu().tolist())
                all_targets.extend(targets.cpu().tolist())

                if show_progress:
                    current_loss = running_loss / (batch_idx + 1)
                    current_acc = 100.0 * correct / total

                    display_progress_bar(
                        batch_idx=batch_idx,
                        num_batches=num_batches,
                        loss=current_loss,
                        accuracy=current_acc,
                    )

        if show_progress:
            print()

        epoch_loss = running_loss / num_batches
        epoch_acc = 100.0 * accuracy_score(all_targets, all_preds)

        return epoch_loss, epoch_acc, all_preds, all_targets

    
    def _upload_checkpoint_to_wandb(self, model_path, model_name, epoch, metrics):
        artifact = wandb.Artifact(
            name=model_name,
            type='model',
            metadata=metrics,
        )
        artifact.add_file(str(model_path))
        wandb.log_artifact(artifact, aliases=['latest', f'epoch-{epoch}', 'best'])
        print(f'    ☁️  Uploaded to W&B Artifacts (epoch-{epoch})')

        
    def fit(
        self,
        trainloader,
        valloader,
        epochs=10,
        patience=5,
        delta=1e-4,
        model_name="model",
        topk=5,
        use_wandb=False
    ):
        best_vloss = float("inf")
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        start_time = time.time()
        early_stopping = EarlyStopping(patience=patience, delta=delta)
        topk_models = []

        for epoch in range(epochs):
            model_path = f"{model_name}_e{epoch+1}_{timestamp}.pt"

            print(f"\nEpoch {epoch + 1}/{epochs} - Training")
            t_loss, t_acc, _, _ = self._run_epoch(
                trainloader, training=True, show_progress=True
            )
            v_loss, v_acc, _, _ = self._run_epoch(
                valloader, training=False, show_progress=True
            )

            if self.scheduler:
                self.scheduler.step()

            # Log Metrics
            self.history["train_loss"].append(t_loss)
            self.history["train_acc"].append(t_acc)
            self.history["val_loss"].append(v_loss)
            self.history["val_acc"].append(v_acc)

            current_lr = self.optimizer.param_groups[0]['lr']
            if use_wandb:
                wandb.log({
                    'train_loss': t_loss,
                    'train_acc': t_acc,
                    'val_loss':   v_loss,
                    'val_acc':   v_acc,
                    'lr':         current_lr,
                    'epoch':      epoch,
                }, step=epoch+1)

            # Top K model saved
            if v_loss < best_vloss:
                best_vloss = v_loss
                checkpoint = {
                    'epoch':           epoch+1,
                    'model_state':     {k: v.cpu().clone() for k, v in self.model.state_dict().items()},
                    'optimizer_state': self.optimizer.state_dict(),
                    'scheduler_state': self.scheduler.state_dict() if self.scheduler else None,
                    'val_loss':        v_loss,
                    'val_acc':         v_acc,
                    'history':         self.history,
                }
                torch.save(checkpoint, model_path)
                print(
                    f"\n--> NEW RECORD: Best model saved (Val loss: {best_vloss:.4f})"
                )

                if use_wandb:
                    self._upload_checkpoint_to_wandb(
                        model_path, model_name, epoch,
                        metrics={'val_loss': v_loss, 'val_acc': v_acc, 'epoch': epoch}
                    )
                
                topk_models.append((v_loss, model_path))
                topk_models.sort(key=lambda x: x[0])

                if topk_models is not None and len(topk_models) > topk:
                    _, worst_path = topk_models.pop(-1)
                    if os.path.exists(worst_path):
                        os.remove(worst_path)

            # Early Stopping
            early_stopping(val_loss=v_loss, model=self.model)

            if early_stopping.early_stop:
                print(
                    f"\nEarly stopping at epoch {epoch+1} with best validation loss: {early_stopping.best_loss:.4f}"
                )
                early_stopping.load_best_model(self.model)
                break

            print(f"\nTrain Loss: {t_loss:.4f}, Train Acc: {t_acc:.2f}%")
            print(f"Validation Loss: {v_loss:.4f}, Validation Acc: {v_acc:.2f}%")

        elapsed = time.time() - start_time
        print(f"\nTraining complete in {elapsed // 60:.0f}m {elapsed % 60:.0f}s")

        return self.history

    
    def load_checkpoint(self, model_path):
        ckpt = torch.load(model_path, map_location=self.device)
        self.model.load_state_dict(ckpt['model_state'])
        if 'optimizer_state' in ckpt and ckpt['optimizer_state']:
            self.optimizer.load_state_dict(ckpt['optimizer_state'])
        if 'scheduler_state' in ckpt and self.scheduler and ckpt['scheduler_state']:
            self.scheduler.load_state_dict(ckpt['scheduler_state'])
        if 'history' in ckpt:
            self.history = ckpt['history']
        epoch = ckpt.get('epoch', 0)
        print(f'✅ Checkpoint loaded — epoch {epoch}, val_loss: {ckpt.get("val_loss", "N/A")}')
        return epoch

    
    def evaluate(self, testloader, model_path=None):
        if model_path:
            ckpt = torch.load(model_path, map_location=self.device)
            if 'model_state' in ckpt:
                self.model.load_state_dict(ckpt['model_state'])
            else:
                self.model.load_state_dict(ckpt)

        loss, acc, preds, targets = self._run_epoch(
            testloader, training=False, show_progress=True
        )

        metrics = {
            "loss": loss,
            "accuracy": acc / 100,
            "precision": precision_score(targets, preds, average="weighted", zero_division=0),
            "recall": recall_score(targets, preds, average='weighted', zero_division=0),
            "f1": f1_score(targets, preds, average="weighted", zero_division=0),
        }

        print("\n" + "=" * 25 + "\nTEST SET RESULTS\n" + "=" * 25)

        for k, v in metrics.items():
            print(f"{k.capitalize():<10}: {v:.4f}")

        return preds, targets, metrics

# %%
def count_parameters(model):
    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return total_params, trainable_params

# %%
def get_dataset_mean_std(loader):
    ch_sum = ch_sq_sum = 0.0
    n = 0
    for data, _ in loader:
        ch_sum    += torch.mean(data, dim=[0, 2, 3])
        ch_sq_sum += torch.mean(data ** 2, dim=[0, 2, 3])
        n += 1
    mean = ch_sum / n
    std  = (ch_sq_sum / n - mean ** 2).sqrt()
    return mean, std

# %% [markdown]
# # Dataset

# %%
class KidneyDataset(Dataset):
    def __init__(self, csv_dir, root_dir, transform=None):
        self.csv = pd.read_csv(csv_dir)
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.csv)

    def __getitem__(self, idx):
        row = self.csv.iloc[idx]
        img_path = self.root_dir / row['diag'] / (row['image_id'] + '.jpg')
        img = Image.open(img_path).convert('RGB')
        label = row['target']

        if self.transform is not None:
            img = self.transform(img)

        return img, label

# %% [markdown]
# # Train/Test/Val Split

# %%
temp_dataset = KidneyDataset(CONFIG['csv_dir'], CONFIG['root_dir'], transform=None)
all_labels   = temp_dataset.csv['Class']
indices      = list(range(len(temp_dataset)))

train_indices, temp_indices = train_test_split(
    indices,
    test_size=0.30,
    stratify=all_labels,
    random_state=CONFIG['seed'],
    shuffle=True
)
temp_labels = [all_labels[i] for i in temp_indices]
val_indices, test_indices = train_test_split(
    temp_indices,
    test_size=0.50,
    stratify=temp_labels,
    random_state=CONFIG['seed'],
    shuffle=True
)

print(f'Dataset total : {len(indices)}')
print(f'Train         : {len(train_indices)} ({len(train_indices)/len(indices)*100:.1f}%)')
print(f'Validation    : {len(val_indices)} ({len(val_indices)/len(indices)*100:.1f}%)')
print(f'Test          : {len(test_indices)} ({len(test_indices)/len(indices)*100:.1f}%)')
# Out:
# Dataset total : 12446
# Train         : 8712 (70.0%)
# Validation    : 1867 (15.0%)
# Test          : 1867 (15.0%)

# %% [markdown]
# # Dataset mean & std
# - skipped if values are pre-filled in Conifg

# %%
if CONFIG['mean'] is None or CONFIG['std'] is None:
    print('Computing dataset mean & std on the training split...')
    stats_transform = v2.Compose([
        v2.Resize((CONFIG['input_dim'], CONFIG['input_dim'])),
        v2.ToImage(),
        v2.ToDtype(torch.float32, scale=True),
    ])
    stats_base    = KidneyDataset(CONFIG['csv_dir'], CONFIG['root_dir'], transform=stats_transform)
    stats_dataset = Subset(stats_base, train_indices)
    stats_loader  = DataLoader(stats_dataset, batch_size=64, shuffle=False)

    mean, std = get_dataset_mean_std(stats_loader)
    CONFIG['mean'] = mean.tolist()
    CONFIG['std']  = std.tolist()
    print(f'  ➜ Paste these into CONFIG to skip next time:')
    print(f'    "mean": {CONFIG["mean"]},')
    print(f'    "std" : {CONFIG["std"]},')
else:
    print(f'Using cached stats — mean: {CONFIG["mean"]}, std: {CONFIG["std"]}')
# Out:
# Using cached stats — mean: [0.1438080370426178, 0.1438080370426178, 0.1438080370426178], std: [0.233843594789505, 0.233843594789505, 0.233843594789505]

# %% [markdown]
# # Transform & Dataloaders

# %%
mean = CONFIG['mean']
std  = CONFIG['std']
input_dim  = CONFIG['input_dim']

train_transform = v2.Compose([
    v2.Resize((input_dim, input_dim)),
    v2.RandomHorizontalFlip(p=0.5),
    v2.RandomRotation(degrees=5),
    v2.RandomAffine(degrees=0, translate=(0.1, 0.1), scale=(0.9, 1.1)),
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
    v2.Normalize(mean=mean, std=std),
])

val_transform = v2.Compose([
    v2.Resize((input_dim, input_dim)),
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
    v2.Normalize(mean=mean, std=std),
])

train_base = KidneyDataset(CONFIG['csv_dir'], CONFIG['root_dir'], transform=train_transform)
val_base = KidneyDataset(CONFIG['csv_dir'], CONFIG['root_dir'], transform=val_transform)
test_base  = KidneyDataset(CONFIG['csv_dir'], CONFIG['root_dir'], transform=val_transform)

train_dataset = Subset(train_base, train_indices)
val_dataset = Subset(val_base, val_indices)
test_dataset = Subset(test_base, test_indices)

train_loader = DataLoader(
    train_dataset,
    batch_size=CONFIG['batch_size'],
    shuffle=True,
    pin_memory=True
)
val_loader = DataLoader(
    val_dataset,
    batch_size=CONFIG['batch_size'],
    shuffle=False,
    pin_memory=True,
    num_workers=2
)
test_loader = DataLoader(
    test_dataset,
    batch_size=CONFIG['batch_size'], 
    shuffle=False,
    pin_memory=True,
    num_workers=2
)

print(f"Training set: {len(train_dataset)}")
print(f"Val set: {len(val_dataset)}")
print(f"Test set: {len(test_dataset)}")
# Out:
# Training set: 8712
# Val set: 1867
# Test set: 1867

# %% [markdown]
# # Model & Optimizer

# %%
from torchvision.models import swin_t

model = swin_t(
    weights=None,
    num_classes=CONFIG["num_classes"]
)

# Count parameters
total_params, trainable_params = count_parameters(model)
print(f"Total parameters: {total_params}")
print(f"Trainable parameters: {trainable_params}")

# Define loss and optimizer
class_weights = torch.tensor(CONFIG['class_weights'], dtype=torch.float32).to(device)
criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = optim.AdamW(model.parameters(), lr=CONFIG['lr'], weight_decay=CONFIG['weight_decay'])

def warmup_cosine_lambda(epoch, warmup_epochs, total_epochs):
    if epoch < warmup_epochs:
        return (epoch + 1) / warmup_epochs
    progress = (epoch - warmup_epochs) / max(1, total_epochs - warmup_epochs)
    return 0.5 * (1 + math.cos(math.pi * progress))

scheduler = optim.lr_scheduler.LambdaLR(
    optimizer,
    lr_lambda=lambda e: warmup_cosine_lambda(e, CONFIG['warmup_epochs'], CONFIG['epochs'])
)

if CONFIG['use_wandb']:
    wandb.init(
        project=CONFIG['wandb_project'],
        name=f"{CONFIG["model"].lower()}_{CONFIG["variant"]}_exp{CONFIG["exp_no"]}_{datetime.now().strftime('%Y%m%d_%H%M')}",
        config={k: v for k, v in CONFIG.items() if k not in ('device', 'root_dir', 'output_dir')}
    )
    print('✅ W&B initialized')
else:
    print('ℹ️  W&B disabled — set CONFIG["use_wandb"] = True to enable')

trainer = Trainer(
    model=model,
    device=device,
    optimizer=optimizer,
    criterion=criterion,
    scheduler=scheduler
)

print('✅ Trainer ready')
# Out:
# Total parameters: 27522430
# Trainable parameters: 27522430
# wandb: setting up run rb6v7ojt
# wandb: Tracking run with wandb version 0.24.0
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20260219_133747-rb6v7ojt
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run swin_tiny_exp5_20260219_1337
# wandb: ⭐️ View project at https://wandb.ai/davian-yang/kidney-stone-ct
# wandb: 🚀 View run at https://wandb.ai/davian-yang/kidney-stone-ct/runs/rb6v7ojt
# ✅ W&B initialized
# ✅ Trainer ready

# %% [markdown]
# # Run Training

# %%
history = trainer.fit(
    trainloader=train_loader,
    valloader=val_loader,
    epochs=CONFIG['epochs'],
    patience=CONFIG['patience'],
    delta=CONFIG['delta'],
    model_name=f"{CONFIG["model"].lower()}_{CONFIG["variant"]}_exp{CONFIG["exp_no"]}",
    use_wandb=CONFIG['use_wandb'],
    topk=CONFIG['max_saved_models']
)
# Out:
# Epoch 1/100 - Training
# [========================================] 137/137 | Loss: 1.140 | Accuracy: 46.87%
# [========================================] 30/30 | Loss: 1.003 | Accuracy: 49.87%
#
# --> NEW RECORD: Best model saved (Val loss: 1.0030)
#     ☁️  Uploaded to W&B Artifacts (epoch-0)
#
# Train Loss: 1.1403, Train Acc: 46.87%
# Validation Loss: 1.0030, Validation Acc: 49.87%
#
# Epoch 2/100 - Training
# [========================================] 137/137 | Loss: 1.019 | Accuracy: 54.83%
# [========================================] 30/30 | Loss: 1.043 | Accuracy: 64.76%
#
# Train Loss: 1.0186, Train Acc: 54.83%
# Validation Loss: 1.0429, Validation Acc: 64.76%
#
# Epoch 3/100 - Training
# [========================================] 137/137 | Loss: 0.927 | Accuracy: 59.92%
# [========================================] 30/30 | Loss: 0.820 | Accuracy: 63.69%
#
# --> NEW RECORD: Best model saved (Val loss: 0.8203)
#     ☁️  Uploaded to W&B Artifacts (epoch-2)
#
# Train Loss: 0.9272, Train Acc: 59.92%
# Validation Loss: 0.8203, Validation Acc: 63.69%
#
# Epoch 4/100 - Training
# [========================================] 137/137 | Loss: 0.842 | Accuracy: 63.90%
# [========================================] 30/30 | Loss: 0.838 | Accuracy: 74.50%
#
# Train Loss: 0.8421, Train Acc: 63.90%
# Validation Loss: 0.8377, Validation Acc: 74.50%
#
# Epoch 5/100 - Training
# [========================================] 137/137 | Loss: 0.777 | Accuracy: 67.10%
# [========================================] 30/30 | Loss: 0.790 | Accuracy: 64.86%
#
# --> NEW RECORD: Best model saved (Val loss: 0.7904)
#     ☁️  Uploaded to W&B Artifacts (epoch-4)
#
# Train Loss: 0.7770, Train Acc: 67.10%
# Validation Loss: 0.7904, Validation Acc: 64.86%
#
# Epoch 6/100 - Training
# [========================================] 137/137 | Loss: 0.737 | Accuracy: 69.55%
# [========================================] 30/30 | Loss: 0.880 | Accuracy: 56.88%
#
# Train Loss: 0.7373, Train Acc: 69.55%
# Validation Loss: 0.8802, Validation Acc: 56.88%
#
# Epoch 7/100 - Training
# [========================================] 137/137 | Loss: 0.706 | Accuracy: 70.44%
# [========================================] 30/30 | Loss: 0.682 | Accuracy: 74.72%
#
# --> NEW RECORD: Best model saved (Val loss: 0.6820)
#     ☁️  Uploaded to W&B Artifacts (epoch-6)
#
# Train Loss: 0.7062, Train Acc: 70.44%
# Validation Loss: 0.6820, Validation Acc: 74.72%
#
# Epoch 8/100 - Training
# [========================================] 137/137 | Loss: 0.651 | Accuracy: 73.01%
# [========================================] 30/30 | Loss: 0.697 | Accuracy: 74.13%
#
# Train Loss: 0.6506, Train Acc: 73.01%
# Validation Loss: 0.6968, Validation Acc: 74.13%
#
# Epoch 9/100 - Training
# [========================================] 137/137 | Loss: 0.644 | Accuracy: 73.00%
# [========================================] 30/30 | Loss: 0.580 | Accuracy: 76.00%
#
# --> NEW RECORD: Best model saved (Val loss: 0.5799)
#     ☁️  Uploaded to W&B Artifacts (epoch-8)
#
# Train Loss: 0.6443, Train Acc: 73.00%
# Validation Loss: 0.5799, Validation Acc: 76.00%
#
# Epoch 10/100 - Training
# [========================================] 137/137 | Loss: 0.637 | Accuracy: 74.01%
# [========================================] 30/30 | Loss: 0.696 | Accuracy: 77.24%
#
# Train Loss: 0.6374, Train Acc: 74.01%
# Validation Loss: 0.6964, Validation Acc: 77.24%
#
# Epoch 11/100 - Training
# [========================================] 137/137 | Loss: 0.587 | Accuracy: 76.65%
# [========================================] 30/30 | Loss: 0.577 | Accuracy: 73.33%
#
# --> NEW RECORD: Best model saved (Val loss: 0.5767)
#     ☁️  Uploaded to W&B Artifacts (epoch-10)
#
# Train Loss: 0.5866, Train Acc: 76.65%
# Validation Loss: 0.5767, Validation Acc: 73.33%
#
# Epoch 12/100 - Training
# [========================================] 137/137 | Loss: 0.627 | Accuracy: 74.14%
# [========================================] 30/30 | Loss: 0.575 | Accuracy: 81.52%
#
# --> NEW RECORD: Best model saved (Val loss: 0.5752)
#     ☁️  Uploaded to W&B Artifacts (epoch-11)
#
# Train Loss: 0.6268, Train Acc: 74.14%
# Validation Loss: 0.5752, Validation Acc: 81.52%
#
# Epoch 13/100 - Training
# [========================================] 137/137 | Loss: 0.571 | Accuracy: 77.16%
# [========================================] 30/30 | Loss: 0.482 | Accuracy: 80.24%
#
# --> NEW RECORD: Best model saved (Val loss: 0.4820)
#     ☁️  Uploaded to W&B Artifacts (epoch-12)
#
# Train Loss: 0.5707, Train Acc: 77.16%
# Validation Loss: 0.4820, Validation Acc: 80.24%
#
# Epoch 14/100 - Training
# [========================================] 137/137 | Loss: 0.567 | Accuracy: 76.85%
# [========================================] 30/30 | Loss: 0.504 | Accuracy: 77.61%
#
# Train Loss: 0.5668, Train Acc: 76.85%
# Validation Loss: 0.5036, Validation Acc: 77.61%
#
# Epoch 15/100 - Training
# [========================================] 137/137 | Loss: 0.519 | Accuracy: 79.02%
# [========================================] 30/30 | Loss: 0.642 | Accuracy: 72.90%
#
# Train Loss: 0.5194, Train Acc: 79.02%
# Validation Loss: 0.6423, Validation Acc: 72.90%
#
# Epoch 16/100 - Training
# [========================================] 137/137 | Loss: 0.493 | Accuracy: 79.87%
# [========================================] 30/30 | Loss: 0.473 | Accuracy: 78.84%
#
# --> NEW RECORD: Best model saved (Val loss: 0.4733)
#     ☁️  Uploaded to W&B Artifacts (epoch-15)
#
# Train Loss: 0.4932, Train Acc: 79.87%
# Validation Loss: 0.4733, Validation Acc: 78.84%
#
# Epoch 17/100 - Training
# [========================================] 137/137 | Loss: 0.482 | Accuracy: 80.10%
# [========================================] 30/30 | Loss: 0.505 | Accuracy: 77.40%
#
# Train Loss: 0.4819, Train Acc: 80.10%
# Validation Loss: 0.5046, Validation Acc: 77.40%
#
# Epoch 18/100 - Training
# [========================================] 137/137 | Loss: 0.514 | Accuracy: 79.10%
# [========================================] 30/30 | Loss: 0.430 | Accuracy: 85.81%
#
# --> NEW RECORD: Best model saved (Val loss: 0.4302)
#     ☁️  Uploaded to W&B Artifacts (epoch-17)
#
# Train Loss: 0.5137, Train Acc: 79.10%
# Validation Loss: 0.4302, Validation Acc: 85.81%
#
# Epoch 19/100 - Training
# [========================================] 137/137 | Loss: 0.455 | Accuracy: 81.73%
# [========================================] 30/30 | Loss: 0.357 | Accuracy: 88.27%
#
# --> NEW RECORD: Best model saved (Val loss: 0.3571)
#     ☁️  Uploaded to W&B Artifacts (epoch-18)
#
# Train Loss: 0.4548, Train Acc: 81.73%
# Validation Loss: 0.3571, Validation Acc: 88.27%
#
# Epoch 20/100 - Training
# [========================================] 137/137 | Loss: 0.440 | Accuracy: 81.85%
# [========================================] 30/30 | Loss: 0.558 | Accuracy: 76.49%
#
# Train Loss: 0.4400, Train Acc: 81.85%
# Validation Loss: 0.5576, Validation Acc: 76.49%
#
# Epoch 21/100 - Training
# [========================================] 137/137 | Loss: 0.449 | Accuracy: 81.71%
# [========================================] 30/30 | Loss: 0.339 | Accuracy: 88.32%
#
# --> NEW RECORD: Best model saved (Val loss: 0.3393)
#     ☁️  Uploaded to W&B Artifacts (epoch-20)
#
# Train Loss: 0.4493, Train Acc: 81.71%
# Validation Loss: 0.3393, Validation Acc: 88.32%
#
# Epoch 22/100 - Training
# [========================================] 137/137 | Loss: 0.439 | Accuracy: 82.09%
# [========================================] 30/30 | Loss: 0.541 | Accuracy: 77.34%
#
# Train Loss: 0.4394, Train Acc: 82.09%
# Validation Loss: 0.5414, Validation Acc: 77.34%
#
# Epoch 23/100 - Training
# [========================================] 137/137 | Loss: 0.433 | Accuracy: 82.04%
# [========================================] 30/30 | Loss: 0.734 | Accuracy: 64.70%
#
# Train Loss: 0.4329, Train Acc: 82.04%
# Validation Loss: 0.7341, Validation Acc: 64.70%
#
# Epoch 24/100 - Training
# [========================================] 137/137 | Loss: 0.441 | Accuracy: 82.59%
# [========================================] 30/30 | Loss: 0.512 | Accuracy: 75.47%
#
# Train Loss: 0.4412, Train Acc: 82.59%
# Validation Loss: 0.5123, Validation Acc: 75.47%
#
# Epoch 25/100 - Training
# [========================================] 137/137 | Loss: 0.421 | Accuracy: 82.50%
# [========================================] 30/30 | Loss: 0.405 | Accuracy: 83.88%
#
# Train Loss: 0.4214, Train Acc: 82.50%
# Validation Loss: 0.4048, Validation Acc: 83.88%
#
# Epoch 26/100 - Training
# [========================================] 137/137 | Loss: 0.375 | Accuracy: 84.77%
# [========================================] 30/30 | Loss: 0.312 | Accuracy: 87.90%
#
# --> NEW RECORD: Best model saved (Val loss: 0.3125)
#     ☁️  Uploaded to W&B Artifacts (epoch-25)
#
# Train Loss: 0.3749, Train Acc: 84.77%
# Validation Loss: 0.3125, Validation Acc: 87.90%
#
# Epoch 27/100 - Training
# [========================================] 137/137 | Loss: 0.377 | Accuracy: 84.16%
# [========================================] 30/30 | Loss: 0.318 | Accuracy: 87.25%
#
# Train Loss: 0.3773, Train Acc: 84.16%
# Validation Loss: 0.3176, Validation Acc: 87.25%
#
# Epoch 28/100 - Training
# [========================================] 137/137 | Loss: 0.348 | Accuracy: 86.44%
# [========================================] 30/30 | Loss: 0.347 | Accuracy: 84.15%
#
# Train Loss: 0.3478, Train Acc: 86.44%
# Validation Loss: 0.3465, Validation Acc: 84.15%
#
# Epoch 29/100 - Training
# [========================================] 137/137 | Loss: 0.351 | Accuracy: 85.89%
# [========================================] 30/30 | Loss: 0.338 | Accuracy: 85.32%
#
# Train Loss: 0.3514, Train Acc: 85.89%
# Validation Loss: 0.3376, Validation Acc: 85.32%
#
# Epoch 30/100 - Training
# [========================================] 137/137 | Loss: 0.341 | Accuracy: 86.33%
# [========================================] 30/30 | Loss: 0.239 | Accuracy: 90.09%
#
# --> NEW RECORD: Best model saved (Val loss: 0.2392)
#     ☁️  Uploaded to W&B Artifacts (epoch-29)
#
# Train Loss: 0.3406, Train Acc: 86.33%
# Validation Loss: 0.2392, Validation Acc: 90.09%
#
# Epoch 31/100 - Training
# [========================================] 137/137 | Loss: 0.335 | Accuracy: 86.46%
# [========================================] 30/30 | Loss: 0.399 | Accuracy: 83.93%
#
# Train Loss: 0.3350, Train Acc: 86.46%
# Validation Loss: 0.3993, Validation Acc: 83.93%
#
# Epoch 32/100 - Training
# [========================================] 137/137 | Loss: 0.345 | Accuracy: 85.59%
# [========================================] 30/30 | Loss: 0.354 | Accuracy: 78.41%
#
# Train Loss: 0.3452, Train Acc: 85.59%
# Validation Loss: 0.3539, Validation Acc: 78.41%
#
# Epoch 33/100 - Training
# [========================================] 137/137 | Loss: 0.333 | Accuracy: 86.09%
# [========================================] 30/30 | Loss: 0.247 | Accuracy: 89.72%
#
# Train Loss: 0.3328, Train Acc: 86.09%
# Validation Loss: 0.2475, Validation Acc: 89.72%
#
# Epoch 34/100 - Training
# [========================================] 137/137 | Loss: 0.309 | Accuracy: 87.59%
# [========================================] 30/30 | Loss: 0.286 | Accuracy: 87.04%
#
# Train Loss: 0.3089, Train Acc: 87.59%
# Validation Loss: 0.2856, Validation Acc: 87.04%
#
# Epoch 35/100 - Training
# [========================================] 137/137 | Loss: 0.317 | Accuracy: 87.04%
# [========================================] 30/30 | Loss: 0.231 | Accuracy: 90.47%
#
# --> NEW RECORD: Best model saved (Val loss: 0.2315)
#     ☁️  Uploaded to W&B Artifacts (epoch-34)
#
# Train Loss: 0.3175, Train Acc: 87.04%
# Validation Loss: 0.2315, Validation Acc: 90.47%
#
# Epoch 36/100 - Training
# [========================================] 137/137 | Loss: 0.276 | Accuracy: 88.74%
# [========================================] 30/30 | Loss: 0.245 | Accuracy: 89.98%
#
# Train Loss: 0.2758, Train Acc: 88.74%
# Validation Loss: 0.2453, Validation Acc: 89.98%
#
# Epoch 37/100 - Training
# [========================================] 137/137 | Loss: 0.294 | Accuracy: 88.12%
# [========================================] 30/30 | Loss: 0.246 | Accuracy: 88.06%
#
# Train Loss: 0.2940, Train Acc: 88.12%
# Validation Loss: 0.2460, Validation Acc: 88.06%
#
# Epoch 38/100 - Training
# [========================================] 137/137 | Loss: 0.264 | Accuracy: 89.05%
# [========================================] 30/30 | Loss: 0.216 | Accuracy: 90.68%
#
# --> NEW RECORD: Best model saved (Val loss: 0.2158)
#     ☁️  Uploaded to W&B Artifacts (epoch-37)
#
# Train Loss: 0.2642, Train Acc: 89.05%
# Validation Loss: 0.2158, Validation Acc: 90.68%
#
# Epoch 39/100 - Training
# [========================================] 137/137 | Loss: 0.256 | Accuracy: 89.41%
# [========================================] 30/30 | Loss: 0.184 | Accuracy: 93.68%
#
# --> NEW RECORD: Best model saved (Val loss: 0.1837)
#     ☁️  Uploaded to W&B Artifacts (epoch-38)
#
# Train Loss: 0.2556, Train Acc: 89.41%
# Validation Loss: 0.1837, Validation Acc: 93.68%
#
# Epoch 40/100 - Training
# [========================================] 137/137 | Loss: 0.284 | Accuracy: 88.14%
# [========================================] 30/30 | Loss: 0.202 | Accuracy: 90.41%
#
# Train Loss: 0.2840, Train Acc: 88.14%
# Validation Loss: 0.2018, Validation Acc: 90.41%
#
# Epoch 41/100 - Training
# [========================================] 137/137 | Loss: 0.246 | Accuracy: 90.06%
# [========================================] 30/30 | Loss: 0.189 | Accuracy: 91.11%
#
# Train Loss: 0.2460, Train Acc: 90.06%
# Validation Loss: 0.1887, Validation Acc: 91.11%
#
# Epoch 42/100 - Training
# [========================================] 137/137 | Loss: 0.217 | Accuracy: 91.17%
# [========================================] 30/30 | Loss: 0.162 | Accuracy: 93.95%
#
# --> NEW RECORD: Best model saved (Val loss: 0.1622)
#     ☁️  Uploaded to W&B Artifacts (epoch-41)
#
# Train Loss: 0.2166, Train Acc: 91.17%
# Validation Loss: 0.1622, Validation Acc: 93.95%
#
# Epoch 43/100 - Training
# [========================================] 137/137 | Loss: 0.217 | Accuracy: 91.64%
# [========================================] 30/30 | Loss: 0.166 | Accuracy: 94.48%
#
# Train Loss: 0.2165, Train Acc: 91.64%
# Validation Loss: 0.1658, Validation Acc: 94.48%
#
# Epoch 44/100 - Training
# [========================================] 137/137 | Loss: 0.256 | Accuracy: 89.82%
# [========================================] 30/30 | Loss: 0.168 | Accuracy: 91.97%
#
# Train Loss: 0.2561, Train Acc: 89.82%
# Validation Loss: 0.1677, Validation Acc: 91.97%
#
# Epoch 45/100 - Training
# [========================================] 137/137 | Loss: 0.224 | Accuracy: 90.78%
# [========================================] 30/30 | Loss: 0.171 | Accuracy: 93.89%
#
# Train Loss: 0.2244, Train Acc: 90.78%
# Validation Loss: 0.1712, Validation Acc: 93.89%
#
# Epoch 46/100 - Training
# [========================================] 137/137 | Loss: 0.222 | Accuracy: 91.09%
# [========================================] 30/30 | Loss: 0.137 | Accuracy: 95.18%
#
# --> NEW RECORD: Best model saved (Val loss: 0.1366)
#     ☁️  Uploaded to W&B Artifacts (epoch-45)
#
# Train Loss: 0.2224, Train Acc: 91.09%
# Validation Loss: 0.1366, Validation Acc: 95.18%
#
# Epoch 47/100 - Training
# [========================================] 137/137 | Loss: 0.182 | Accuracy: 92.46%
# [========================================] 30/30 | Loss: 0.140 | Accuracy: 94.32%
#
# Train Loss: 0.1819, Train Acc: 92.46%
# Validation Loss: 0.1396, Validation Acc: 94.32%
#
# Epoch 48/100 - Training
# [========================================] 137/137 | Loss: 0.213 | Accuracy: 91.43%
# [========================================] 30/30 | Loss: 0.190 | Accuracy: 92.13%
#
# Train Loss: 0.2132, Train Acc: 91.43%
# Validation Loss: 0.1897, Validation Acc: 92.13%
#
# Epoch 49/100 - Training
# [========================================] 137/137 | Loss: 0.229 | Accuracy: 91.07%
# [========================================] 30/30 | Loss: 0.154 | Accuracy: 92.77%
#
# Train Loss: 0.2286, Train Acc: 91.07%
# Validation Loss: 0.1541, Validation Acc: 92.77%
#
# Epoch 50/100 - Training
# [========================================] 137/137 | Loss: 0.167 | Accuracy: 93.19%
# [========================================] 30/30 | Loss: 0.161 | Accuracy: 92.66%
#
# Train Loss: 0.1675, Train Acc: 93.19%
# Validation Loss: 0.1605, Validation Acc: 92.66%
#
# Epoch 51/100 - Training
# [========================================] 137/137 | Loss: 0.176 | Accuracy: 92.87%
# [========================================] 30/30 | Loss: 0.109 | Accuracy: 94.75%
#
# --> NEW RECORD: Best model saved (Val loss: 0.1086)
#     ☁️  Uploaded to W&B Artifacts (epoch-50)
#
# Train Loss: 0.1759, Train Acc: 92.87%
# Validation Loss: 0.1086, Validation Acc: 94.75%
#
# Epoch 52/100 - Training
# [========================================] 137/137 | Loss: 0.168 | Accuracy: 93.33%
# [========================================] 30/30 | Loss: 0.088 | Accuracy: 95.72%
#
# --> NEW RECORD: Best model saved (Val loss: 0.0882)
#     ☁️  Uploaded to W&B Artifacts (epoch-51)
#
# Train Loss: 0.1682, Train Acc: 93.33%
# Validation Loss: 0.0882, Validation Acc: 95.72%
#
# Epoch 53/100 - Training
# [========================================] 137/137 | Loss: 0.159 | Accuracy: 93.29%
# [========================================] 30/30 | Loss: 0.186 | Accuracy: 91.91%
#
# Train Loss: 0.1593, Train Acc: 93.29%
# Validation Loss: 0.1860, Validation Acc: 91.91%
#
# Epoch 54/100 - Training
# [========================================] 137/137 | Loss: 0.190 | Accuracy: 92.23%
# [========================================] 30/30 | Loss: 0.090 | Accuracy: 96.04%
#
# Train Loss: 0.1896, Train Acc: 92.23%
# Validation Loss: 0.0904, Validation Acc: 96.04%
#
# Epoch 55/100 - Training
# [========================================] 137/137 | Loss: 0.147 | Accuracy: 94.54%
# [========================================] 30/30 | Loss: 0.082 | Accuracy: 96.95%
#
# --> NEW RECORD: Best model saved (Val loss: 0.0816)
#     ☁️  Uploaded to W&B Artifacts (epoch-54)
#
# Train Loss: 0.1473, Train Acc: 94.54%
# Validation Loss: 0.0816, Validation Acc: 96.95%
#
# Epoch 56/100 - Training
# [========================================] 137/137 | Loss: 0.186 | Accuracy: 92.69%
# [========================================] 30/30 | Loss: 0.088 | Accuracy: 96.41%
#
# Train Loss: 0.1855, Train Acc: 92.69%
# Validation Loss: 0.0883, Validation Acc: 96.41%
#
# Epoch 57/100 - Training
# [========================================] 137/137 | Loss: 0.130 | Accuracy: 94.93%
# [========================================] 30/30 | Loss: 0.132 | Accuracy: 95.18%
#
# Train Loss: 0.1297, Train Acc: 94.93%
# Validation Loss: 0.1323, Validation Acc: 95.18%
#
# Epoch 58/100 - Training
# [========================================] 137/137 | Loss: 0.139 | Accuracy: 94.52%
# [========================================] 30/30 | Loss: 0.099 | Accuracy: 95.29%
#
# Train Loss: 0.1388, Train Acc: 94.52%
# Validation Loss: 0.0991, Validation Acc: 95.29%
#
# Epoch 59/100 - Training
# [========================================] 137/137 | Loss: 0.123 | Accuracy: 94.88%
# [========================================] 30/30 | Loss: 0.096 | Accuracy: 94.97%
#
# Train Loss: 0.1228, Train Acc: 94.88%
# Validation Loss: 0.0955, Validation Acc: 94.97%
#
# Epoch 60/100 - Training
# [========================================] 137/137 | Loss: 0.109 | Accuracy: 95.67%
# [========================================] 30/30 | Loss: 0.049 | Accuracy: 97.54%
#
# --> NEW RECORD: Best model saved (Val loss: 0.0490)
#     ☁️  Uploaded to W&B Artifacts (epoch-59)
#
# Train Loss: 0.1090, Train Acc: 95.67%
# Validation Loss: 0.0490, Validation Acc: 97.54%
#
# Epoch 61/100 - Training
# [========================================] 137/137 | Loss: 0.105 | Accuracy: 95.62%
# [========================================] 30/30 | Loss: 0.050 | Accuracy: 97.43%
#
# Train Loss: 0.1054, Train Acc: 95.62%
# Validation Loss: 0.0498, Validation Acc: 97.43%
#
# Epoch 62/100 - Training
# [========================================] 137/137 | Loss: 0.103 | Accuracy: 95.67%
# [========================================] 30/30 | Loss: 0.062 | Accuracy: 98.55%
#
# Train Loss: 0.1032, Train Acc: 95.67%
# Validation Loss: 0.0623, Validation Acc: 98.55%
#
# Epoch 63/100 - Training
# [========================================] 137/137 | Loss: 0.088 | Accuracy: 96.35%
# [========================================] 30/30 | Loss: 0.065 | Accuracy: 97.05%
#
# Train Loss: 0.0877, Train Acc: 96.35%
# Validation Loss: 0.0649, Validation Acc: 97.05%
#
# Epoch 64/100 - Training
# [========================================] 137/137 | Loss: 0.090 | Accuracy: 96.35%
# [========================================] 30/30 | Loss: 0.052 | Accuracy: 98.13%
#
# Train Loss: 0.0900, Train Acc: 96.35%
# Validation Loss: 0.0522, Validation Acc: 98.13%
#
# Epoch 65/100 - Training
# [========================================] 137/137 | Loss: 0.097 | Accuracy: 96.25%
# [========================================] 30/30 | Loss: 0.062 | Accuracy: 96.14%
#
# Train Loss: 0.0966, Train Acc: 96.25%
# Validation Loss: 0.0618, Validation Acc: 96.14%
#
# Epoch 66/100 - Training
# [========================================] 137/137 | Loss: 0.084 | Accuracy: 96.81%
# [========================================] 30/30 | Loss: 0.042 | Accuracy: 98.39%
#
# --> NEW RECORD: Best model saved (Val loss: 0.0423)
#     ☁️  Uploaded to W&B Artifacts (epoch-65)
#
# Train Loss: 0.0836, Train Acc: 96.81%
# Validation Loss: 0.0423, Validation Acc: 98.39%
#
# Epoch 67/100 - Training
# [========================================] 137/137 | Loss: 0.085 | Accuracy: 96.58%
# [========================================] 30/30 | Loss: 0.047 | Accuracy: 97.80%
#
# Train Loss: 0.0848, Train Acc: 96.58%
# Validation Loss: 0.0473, Validation Acc: 97.80%
#
# Epoch 68/100 - Training
# [========================================] 137/137 | Loss: 0.081 | Accuracy: 96.85%
# [========================================] 30/30 | Loss: 0.042 | Accuracy: 98.29%
#
# --> NEW RECORD: Best model saved (Val loss: 0.0421)
#     ☁️  Uploaded to W&B Artifacts (epoch-67)
#
# Train Loss: 0.0811, Train Acc: 96.85%
# Validation Loss: 0.0421, Validation Acc: 98.29%
#
# Epoch 69/100 - Training
# [========================================] 137/137 | Loss: 0.083 | Accuracy: 96.44%
# [========================================] 30/30 | Loss: 0.034 | Accuracy: 98.45%
#
# --> NEW RECORD: Best model saved (Val loss: 0.0336)
#     ☁️  Uploaded to W&B Artifacts (epoch-68)
#
# Train Loss: 0.0834, Train Acc: 96.44%
# Validation Loss: 0.0336, Validation Acc: 98.45%
#
# Epoch 70/100 - Training
# [========================================] 137/137 | Loss: 0.075 | Accuracy: 96.94%
# [========================================] 30/30 | Loss: 0.040 | Accuracy: 98.23%
#
# Train Loss: 0.0753, Train Acc: 96.94%
# Validation Loss: 0.0404, Validation Acc: 98.23%
#
# Epoch 71/100 - Training
# [========================================] 137/137 | Loss: 0.077 | Accuracy: 96.82%
# [========================================] 30/30 | Loss: 0.026 | Accuracy: 99.20%
#
# --> NEW RECORD: Best model saved (Val loss: 0.0265)
#     ☁️  Uploaded to W&B Artifacts (epoch-70)
#
# Train Loss: 0.0765, Train Acc: 96.82%
# Validation Loss: 0.0265, Validation Acc: 99.20%
#
# Epoch 72/100 - Training
# [========================================] 137/137 | Loss: 0.065 | Accuracy: 97.52%
# [========================================] 30/30 | Loss: 0.039 | Accuracy: 97.91%
#
# Train Loss: 0.0652, Train Acc: 97.52%
# Validation Loss: 0.0385, Validation Acc: 97.91%
#
# Epoch 73/100 - Training
# [========================================] 137/137 | Loss: 0.073 | Accuracy: 97.27%
# [========================================] 30/30 | Loss: 0.034 | Accuracy: 98.23%
#
# Train Loss: 0.0729, Train Acc: 97.27%
# Validation Loss: 0.0342, Validation Acc: 98.23%
#
# Epoch 74/100 - Training
# [========================================] 137/137 | Loss: 0.067 | Accuracy: 97.33%
# [========================================] 30/30 | Loss: 0.025 | Accuracy: 99.04%
#
# --> NEW RECORD: Best model saved (Val loss: 0.0245)
#     ☁️  Uploaded to W&B Artifacts (epoch-73)
#
# Train Loss: 0.0670, Train Acc: 97.33%
# Validation Loss: 0.0245, Validation Acc: 99.04%
#
# Epoch 75/100 - Training
# [========================================] 137/137 | Loss: 0.055 | Accuracy: 97.75%
# [========================================] 30/30 | Loss: 0.020 | Accuracy: 99.41%
#
# --> NEW RECORD: Best model saved (Val loss: 0.0200)
#     ☁️  Uploaded to W&B Artifacts (epoch-74)
#
# Train Loss: 0.0552, Train Acc: 97.75%
# Validation Loss: 0.0200, Validation Acc: 99.41%
#
# Epoch 76/100 - Training
# [========================================] 137/137 | Loss: 0.056 | Accuracy: 97.68%
# [========================================] 30/30 | Loss: 0.025 | Accuracy: 99.14%
#
# Train Loss: 0.0561, Train Acc: 97.68%
# Validation Loss: 0.0254, Validation Acc: 99.14%
#
# Epoch 77/100 - Training
# [========================================] 137/137 | Loss: 0.054 | Accuracy: 97.84%
# [========================================] 30/30 | Loss: 0.021 | Accuracy: 99.04%
#
# Train Loss: 0.0539, Train Acc: 97.84%
# Validation Loss: 0.0209, Validation Acc: 99.04%
#
# Epoch 78/100 - Training
# [========================================] 137/137 | Loss: 0.052 | Accuracy: 97.85%
# [========================================] 30/30 | Loss: 0.019 | Accuracy: 99.20%
#
# --> NEW RECORD: Best model saved (Val loss: 0.0193)
#     ☁️  Uploaded to W&B Artifacts (epoch-77)
#
# Train Loss: 0.0519, Train Acc: 97.85%
# Validation Loss: 0.0193, Validation Acc: 99.20%
#
# Epoch 79/100 - Training
# [========================================] 137/137 | Loss: 0.046 | Accuracy: 98.19%
# [========================================] 30/30 | Loss: 0.023 | Accuracy: 99.09%
#
# Train Loss: 0.0458, Train Acc: 98.19%
# Validation Loss: 0.0226, Validation Acc: 99.09%
#
# Epoch 80/100 - Training
# [========================================] 137/137 | Loss: 0.052 | Accuracy: 98.12%
# [========================================] 30/30 | Loss: 0.022 | Accuracy: 99.14%
#
# Train Loss: 0.0518, Train Acc: 98.12%
# Validation Loss: 0.0217, Validation Acc: 99.14%
#
# Epoch 81/100 - Training
# [========================================] 137/137 | Loss: 0.043 | Accuracy: 98.42%
# [========================================] 30/30 | Loss: 0.020 | Accuracy: 99.14%
#
# Train Loss: 0.0428, Train Acc: 98.42%
# Validation Loss: 0.0198, Validation Acc: 99.14%
#
# Epoch 82/100 - Training
# [========================================] 137/137 | Loss: 0.044 | Accuracy: 98.06%
# [========================================] 30/30 | Loss: 0.016 | Accuracy: 99.36%
#
# --> NEW RECORD: Best model saved (Val loss: 0.0164)
#     ☁️  Uploaded to W&B Artifacts (epoch-81)
#
# Train Loss: 0.0445, Train Acc: 98.06%
# Validation Loss: 0.0164, Validation Acc: 99.36%
#
# Epoch 83/100 - Training
# [========================================] 137/137 | Loss: 0.038 | Accuracy: 98.45%
# [========================================] 30/30 | Loss: 0.015 | Accuracy: 99.30%
#
# --> NEW RECORD: Best model saved (Val loss: 0.0154)
#     ☁️  Uploaded to W&B Artifacts (epoch-82)
#
# Train Loss: 0.0385, Train Acc: 98.45%
# Validation Loss: 0.0154, Validation Acc: 99.30%
#
# Epoch 84/100 - Training
# [========================================] 137/137 | Loss: 0.038 | Accuracy: 98.48%
# [========================================] 30/30 | Loss: 0.016 | Accuracy: 99.63%
#
# Train Loss: 0.0377, Train Acc: 98.48%
# Validation Loss: 0.0157, Validation Acc: 99.63%
#
# Epoch 85/100 - Training
# [========================================] 137/137 | Loss: 0.036 | Accuracy: 98.55%
# [========================================] 30/30 | Loss: 0.015 | Accuracy: 99.52%
#
# --> NEW RECORD: Best model saved (Val loss: 0.0153)
#     ☁️  Uploaded to W&B Artifacts (epoch-84)
#
# Train Loss: 0.0362, Train Acc: 98.55%
# Validation Loss: 0.0153, Validation Acc: 99.52%
#
# Epoch 86/100 - Training
# [========================================] 137/137 | Loss: 0.038 | Accuracy: 98.43%
# [========================================] 30/30 | Loss: 0.021 | Accuracy: 99.14%
#
# Train Loss: 0.0380, Train Acc: 98.43%
# Validation Loss: 0.0207, Validation Acc: 99.14%
#
# Epoch 87/100 - Training
# [========================================] 137/137 | Loss: 0.040 | Accuracy: 98.48%
# [========================================] 30/30 | Loss: 0.012 | Accuracy: 99.57%
#
# --> NEW RECORD: Best model saved (Val loss: 0.0116)
#     ☁️  Uploaded to W&B Artifacts (epoch-86)
#
# Train Loss: 0.0395, Train Acc: 98.48%
# Validation Loss: 0.0116, Validation Acc: 99.57%
#
# Epoch 88/100 - Training
# [========================================] 137/137 | Loss: 0.039 | Accuracy: 98.35%
# [========================================] 30/30 | Loss: 0.015 | Accuracy: 99.41%
#
# Train Loss: 0.0391, Train Acc: 98.35%
# Validation Loss: 0.0149, Validation Acc: 99.41%
#
# Epoch 89/100 - Training
# [========================================] 137/137 | Loss: 0.035 | Accuracy: 98.67%
# [========================================] 30/30 | Loss: 0.010 | Accuracy: 99.57%
#
# --> NEW RECORD: Best model saved (Val loss: 0.0100)
#     ☁️  Uploaded to W&B Artifacts (epoch-88)
#
# Train Loss: 0.0351, Train Acc: 98.67%
# Validation Loss: 0.0100, Validation Acc: 99.57%
#
# Epoch 90/100 - Training
# [========================================] 137/137 | Loss: 0.030 | Accuracy: 98.84%
# [========================================] 30/30 | Loss: 0.016 | Accuracy: 99.41%
#
# Train Loss: 0.0301, Train Acc: 98.84%
# Validation Loss: 0.0158, Validation Acc: 99.41%
#
# Epoch 91/100 - Training
# [========================================] 137/137 | Loss: 0.036 | Accuracy: 98.66%
# [========================================] 30/30 | Loss: 0.011 | Accuracy: 99.41%
#
# Train Loss: 0.0357, Train Acc: 98.66%
# Validation Loss: 0.0109, Validation Acc: 99.41%
#
# Epoch 92/100 - Training
# [========================================] 137/137 | Loss: 0.032 | Accuracy: 98.76%
# [========================================] 30/30 | Loss: 0.010 | Accuracy: 99.36%
#
# Train Loss: 0.0319, Train Acc: 98.76%
# Validation Loss: 0.0103, Validation Acc: 99.36%
#
# Epoch 93/100 - Training
# [========================================] 137/137 | Loss: 0.031 | Accuracy: 98.86%
# [========================================] 30/30 | Loss: 0.010 | Accuracy: 99.52%
#
# --> NEW RECORD: Best model saved (Val loss: 0.0100)
#     ☁️  Uploaded to W&B Artifacts (epoch-92)
#
# Train Loss: 0.0313, Train Acc: 98.86%
# Validation Loss: 0.0100, Validation Acc: 99.52%
#
# Epoch 94/100 - Training
# [========================================] 137/137 | Loss: 0.030 | Accuracy: 98.85%
# [========================================] 30/30 | Loss: 0.009 | Accuracy: 99.63%
#
# --> NEW RECORD: Best model saved (Val loss: 0.0091)
#     ☁️  Uploaded to W&B Artifacts (epoch-93)
#
# Train Loss: 0.0303, Train Acc: 98.85%
# Validation Loss: 0.0091, Validation Acc: 99.63%
#
# Epoch 95/100 - Training
# [========================================] 137/137 | Loss: 0.032 | Accuracy: 98.77%
# [========================================] 30/30 | Loss: 0.010 | Accuracy: 99.57%
#
# Train Loss: 0.0315, Train Acc: 98.77%
# Validation Loss: 0.0098, Validation Acc: 99.57%
#
# Epoch 96/100 - Training
# [========================================] 137/137 | Loss: 0.031 | Accuracy: 98.85%
# [========================================] 30/30 | Loss: 0.009 | Accuracy: 99.57%
#
# --> NEW RECORD: Best model saved (Val loss: 0.0090)
#     ☁️  Uploaded to W&B Artifacts (epoch-95)
#
# Train Loss: 0.0306, Train Acc: 98.85%
# Validation Loss: 0.0090, Validation Acc: 99.57%
#
# Epoch 97/100 - Training
# [========================================] 137/137 | Loss: 0.029 | Accuracy: 98.86%
# [========================================] 30/30 | Loss: 0.009 | Accuracy: 99.63%
#
# Train Loss: 0.0288, Train Acc: 98.86%
# Validation Loss: 0.0095, Validation Acc: 99.63%
#
# Epoch 98/100 - Training
# [========================================] 137/137 | Loss: 0.030 | Accuracy: 98.88%
# [========================================] 30/30 | Loss: 0.009 | Accuracy: 99.63%
#
# Train Loss: 0.0302, Train Acc: 98.88%
# Validation Loss: 0.0091, Validation Acc: 99.63%
#
# Epoch 99/100 - Training
# [========================================] 137/137 | Loss: 0.030 | Accuracy: 98.82%
# [========================================] 30/30 | Loss: 0.009 | Accuracy: 99.63%
#
# Early stopping at epoch 99 with best validation loss: 0.0100
#
# Training complete in 236m 7s

# %% [markdown]
# # Training Curves

# %%
plot_result(
    history,
    title=f"{CONFIG["model"]} {CONFIG["variant"]} - Experiment {CONFIG["exp_no"]} — Training Progress",
    save_path=CONFIG['output_dir'] / f'{CONFIG["model"].lower()}_{CONFIG["variant"]}_exp{CONFIG["exp_no"]}_curves.png'
)
# Out:
# Plot saved to /kaggle/working/swin_tiny_exp5_curves.png

# %% [markdown]
# # Test Evaluation

# %%
saved_models = sorted(
    CONFIG['output_dir'].glob(f"{CONFIG["model"].lower()}_{CONFIG["variant"]}_exp{CONFIG["exp_no"]}*.pt"),
    key=lambda p: p.stat().st_mtime,
    reverse=True
)

if saved_models:
    best_model_path = saved_models[0]
    print(f'Using checkpoint: {best_model_path.name}')
else:
    best_model_path = None
    print('No checkpoint found — evaluating with current model weights')

preds, targets, metrics = trainer.evaluate(test_loader, model_path=best_model_path)
# Out:
# Using checkpoint: swin_tiny_exp5_e96_20260219_133749.pt
# [========================================] 30/30 | Loss: 0.020 | Accuracy: 99.25%
#
# =========================
# TEST SET RESULTS
# =========================
# Loss      : 0.0197
# Accuracy  : 0.9925
# Precision : 0.9925
# Recall    : 0.9925
# F1        : 0.9925

# %% [markdown]
# # Confusion Matrix

# %%
CLASS_NAMES = ['Tumor', 'Normal', 'Stone', 'Cyst']

cm   = confusion_matrix(targets, preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=CLASS_NAMES)

disp.plot(cmap='Blues', xticks_rotation=45)
plt.title("Confusion Matrix - Test Set")
plt.savefig(CONFIG['output_dir'] / f'{CONFIG["model"].lower()}_{CONFIG["variant"]}_exp{CONFIG["exp_no"]}_confusion_matrix.png',
            dpi=150, bbox_inches='tight')
plt.show()
