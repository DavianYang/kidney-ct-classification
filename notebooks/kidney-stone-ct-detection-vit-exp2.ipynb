# %%
import torch
import torchvision
from torchvision.transforms import v2
import torchvision.models as models
import torch.optim as optim
import torch.nn.functional as F
import torch.nn as nn
from torch.utils.data import DataLoader

import os
import math
import random
import numpy as np
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import time
import wandb
from PIL import Image
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, precision_score, recall_score, f1_score, accuracy_score

seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Out:
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
from torch.utils.data import Dataset

class KidneyDataset(Dataset):
    def __init__(self, csv_dir, root_dir, transform=None):
        self.csv = pd.read_csv(csv_dir)
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.csv)

    def __getitem__(self, idx):
        row = self.csv.iloc[idx]
        img_path = self.root_dir / row['diag'] / (row['image_id'] + '.jpg')
        img = Image.open(img_path).convert('RGB')
        label = row['target']

        if self.transform is not None:
            img = self.transform(img)

        return img, label

# %%
# Define color codes for terminal
class Colors:
    RESET = '\033[0m'
    GREEN = '\033[92m'
    RED = '\033[91m'
    YELLOW = '\033[93m'
    CYAN = '\033[96m'

def display_progress_bar(batch_idx, num_batches, loss, accuracy):
    """
    Function to display a colored progress bar.
    Args:
        batch_idx: Current batch index
        num_batches: Total number of batches
        loss: Current loss value
        accuracy: Current accuracy value
    """
    progress = (batch_idx + 1) / num_batches
    bar_length = 40  # Length of the progress bar (number of '==' chars)
    filled_length = int(bar_length * progress)
    bar = f"{Colors.GREEN}{'=' * filled_length}{Colors.RED}{'-' * (bar_length - filled_length)}{Colors.RESET}"

    print(f'\r[{bar}] {batch_idx + 1}/{num_batches} | {Colors.YELLOW}Loss:{Colors.RESET} {loss:.3f} | {Colors.YELLOW}Accuracy:{Colors.RESET} {accuracy:.2f}%', end='', flush=True)

# %%
import matplotlib.pyplot as plt

def plot_result(history, title="Training Progress"):
    epochs = range(1, len(history['train_loss']) + 1)

    plt.figure(figsize=(12, 5))

    # Loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, history['train_loss'], label='Train', color='tomato')
    plt.plot(epochs, history['val_loss'], label='Validation', color='steelblue')
    plt.title("Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend(frameon=False)
    plt.grid(True, linestyle="--", alpha=0.3)

    # Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, history['train_acc'], label='Train', color='mediumseagreen')
    plt.plot(epochs, history['val_acc'], label='Validation', color='black')
    plt.title("Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend(frameon=False)
    plt.grid(True, linestyle="--", alpha=0.3)

    plt.suptitle(title, fontsize=14)
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.show()

# %%
import copy


class EarlyStopping:
    def __init__(self, patience=5, delta=0.0):
        self.patience = patience
        self.delta = delta
        self.best_loss = float("inf")
        self.counter = 0
        self.best_model_state = None
        self.early_stop = False

    def __call__(self, val_loss, model):
        if self.best_loss - val_loss > self.delta:
            self.best_loss = val_loss
            self.best_model_state = self.best_model_state = copy.deepcopy(
                model.state_dict()
            )
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

    def load_best_model(self, model):
        if self.best_model_state is not None:
            model.load_state_dict(self.best_model_state)

# %%
import os
from typing import Optional, Any
from datetime import datetime
import time

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.tensorboard import SummaryWriter

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score


class Trainer:
    def __init__(
        self,
        model: nn.Module,
        device: torch.device,
        optimizer: optim.Optimizer,
        criterion: nn.Module,
        scheduler: Optional[Any] = None,
        log_dir: Optional[str] = "runs",
    ):
        self.model = model.to(device)
        self.device = device
        self.optimizer = optimizer
        self.criterion = criterion
        self.scheduler = scheduler
        self.history = {
            "train_loss": [],
            "train_acc": [],
            "val_loss": [],
            "val_acc": [],
        }

        # TensorBoard
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        self.writer = SummaryWriter(log_dir=os.path.join(log_dir, timestamp))
        print(f"TensorBoard logs will be saved to: {os.path.join(log_dir, timestamp)}")

    def _run_epoch(self, loader, training=True, show_progress=True):
        self.model.train() if training else self.model.eval()

        running_loss = 0.0
        correct = 0
        total = 0
        all_preds, all_targets = [], []
        num_batches = len(loader)

        with torch.set_grad_enabled(training):
            for batch_idx, (inputs, targets) in enumerate(loader):
                inputs = inputs.to(self.device)
                targets = targets.to(self.device)

                outputs = self.model(inputs)
                loss = self.criterion(outputs, targets)

                if training:
                    loss.backward()
                    self.optimizer.step()
                    self.optimizer.zero_grad()

                running_loss += loss.item()
                _, preds = outputs.max(1)
                total += targets.size(0)
                correct += preds.eq(targets).sum().item()

                all_preds.extend(preds.cpu().tolist())
                all_targets.extend(targets.cpu().tolist())

                if show_progress:
                    current_loss = running_loss / (batch_idx + 1)
                    current_acc = 100.0 * correct / total
                    display_progress_bar(
                        batch_idx=batch_idx,
                        num_batches=num_batches,
                        loss=current_loss,
                        accuracy=current_acc,
                    )

        if show_progress:
            print()

        epoch_loss = running_loss / num_batches
        epoch_acc = 100.0 * accuracy_score(all_targets, all_preds)

        return epoch_loss, epoch_acc, all_preds, all_targets

    def fit(
        self,
        trainloader,
        valloader,
        epochs=10,
        patience=20,
        delta=1e-4,
        model_name="model",
        topk=5,
    ):
        best_vloss = float("inf")
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        start_time = time.time()
        early_stopping = EarlyStopping(patience=patience, delta=delta)
        topk_models = []

        for epoch in range(epochs):
            model_path = f"{model_name}_e{epoch}_{timestamp}.pt"

            print(f"\nEpoch {epoch + 1}/{epochs} - Training")
            t_loss, t_acc, _, _ = self._run_epoch(
                trainloader, training=True, show_progress=True
            )
            v_loss, v_acc, _, _ = self._run_epoch(
                valloader, training=False, show_progress=True
            )

            if self.scheduler:
                self.scheduler.step()

            # Log Metrics
            self.history["train_loss"].append(t_loss)
            self.history["train_acc"].append(t_acc)
            self.history["val_loss"].append(v_loss)
            self.history["val_acc"].append(v_acc)

            # TensorBoard logging
            self.writer.add_scalar("Loss/Train", t_loss, epoch)
            self.writer.add_scalar("Loss/Validation", v_loss, epoch)
            self.writer.add_scalar("Accuracy/Train", t_acc, epoch)
            self.writer.add_scalar("Accuracy/Validation", v_acc, epoch)

            # Top K model saved
            if v_loss < best_vloss:
                best_vloss = v_loss
                best_model_weights = {
                    k: v.cpu().clone() for k, v in self.model.state_dict().items()
                }
                torch.save(best_model_weights, model_path)
                print(
                    f"\n--> NEW RECORD: Best model saved (Val loss: {best_vloss:.4f})"
                )
                topk_models.append((v_loss, model_path))
                topk_models.sort(key=lambda x: x[0])

                if topk_models is not None and len(topk_models) > topk:
                    _, worst_path = topk_models.pop(-1)
                    if os.path.exists(worst_path):
                        os.remove(worst_path)

            # Early Stopping
            early_stopping(val_loss=v_loss, model=self.model)

            if early_stopping.early_stop:
                print(
                    f"\nEarly stopping at epoch {epoch+1} with best validation loss: {early_stopping.best_loss:.4f}"
                )
                early_stopping.load_best_model(self.model)
                break

            print(f"\nTrain Loss: {t_loss:.4f}, Train Acc: {t_acc:.2f}%")
            print(f"Validation Loss: {v_loss:.4f}, Validation Acc: {v_acc:.2f}%")

        elapsed = time.time() - start_time
        print(f"\nTraining complete in {elapsed // 60:.0f}m {elapsed % 60:.0f}s")

        # Close TensorBoard writer
        self.writer.close()

        return self.history

    def evaluate(self, testloader, model_path=None):
        if model_path:
            self.model.load_state_dict(torch.load(model_path, map_location=self.device))

        loss, acc, preds, targets = self._run_epoch(
            testloader, training=False, show_progress=True
        )

        metrics = {
            "loss": loss,
            "accuracy": acc / 100,
            "precision": precision_score(
                targets, preds, average="weighted", zero_division=0
            ),
            "f1": f1_score(targets, preds, average="weighted", zero_division=0),
        }

        print("\n" + "=" * 25 + "\nTEST SET RESULTS\n" + "=" * 25)

        for k, v in metrics.items():
            print(f"{k.capitalize():<10}: {v:.4f}")

        return preds, targets, metrics
# Out:
# 2026-02-06 14:24:16.761584: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770387856.940560      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770387856.989377      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770387857.410777      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770387857.410816      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770387857.410819      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770387857.410822      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
def count_parameters(model):
    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return total_params, trainable_params

# %% [markdown]
# ## Training

# %%
from torch.utils.data import Subset
from sklearn.model_selection import train_test_split

classes = 4
input_dim = 128
lr = 3e-4
weight_decay=0.05
epochs = 100
batch_size = 64
max_models=5
patience=5
delta=1e-3

train_transform = v2.Compose([
    v2.Resize((128, 128)),
    v2.RandomHorizontalFlip(p=0.5),
    v2.RandomRotation(degrees=15),
    v2.RandomAffine(degrees=0, translate=(0.1, 0.1), scale=(0.9, 1.1)),
    v2.ToTensor(),
    v2.Normalize(mean=[0.4914, 0.4822, 0.4465],
                         std=[0.2023, 0.1994, 0.2010]),
])

val_transform = v2.Compose([
    v2.Resize((128, 128)),
    v2.ToTensor(),
    v2.Normalize(mean=[0.4914, 0.4822, 0.4465],
                         std=[0.2023, 0.1994, 0.2010]),
])

csv_dir = '/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/kidneyData.csv'
root_dir = Path('/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone')

temp_dataset = KidneyDataset(csv_dir, root_dir, transform=None)
dataset_size = len(temp_dataset)
indices = list(range(dataset_size))

# Split indices (70% train, 15% val, 15% test)
train_indices, temp_indices = train_test_split(indices, test_size=0.30, random_state=42, shuffle=True)
val_indices, test_indices = train_test_split(temp_indices, test_size=0.5, random_state=42, shuffle=True)

# Create 3 different datasets
train_base = KidneyDataset(csv_dir, root_dir, transform=train_transform)
val_base = KidneyDataset(csv_dir, root_dir, transform=val_transform)
test_base = KidneyDataset(csv_dir, root_dir, transform=val_transform)

# Use `Subset` to filter each base dataset by the split indices to ensure train_dataset only use train_transform
train_dataset = Subset(train_base, train_indices)
val_dataset = Subset(val_base, val_indices)
test_dataset = Subset(test_base, test_indices)

train_loader = DataLoader(train_dataset, batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size, shuffle=False)

print(f"Training set: {len(train_dataset)}")
print(f"Val set: {len(val_dataset)}")
print(f"Test set: {len(test_dataset)}")
# Out:
# Training set: 8712
# Val set: 1867
# Test set: 1867
# /usr/local/lib/python3.12/dist-packages/torchvision/transforms/v2/_deprecated.py:42: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.Output is equivalent up to float precision.
#   warnings.warn(

# %%
from torchvision.models import VisionTransformer

vit = VisionTransformer(
    image_size=128,
    patch_size=16,
    hidden_dim=768,
    mlp_dim=3072,
    num_layers=12,
    num_heads=12,
    num_classes=classes
)


# Count parameters
total_params, trainable_params = count_parameters(vit)
print(f"Total parameters: {total_params}")
print(f"Trainable parameters: {trainable_params}")

# Define loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(vit.parameters(), lr=lr, weight_decay=weight_decay)
# Out:
# Total parameters: 85700356
# Trainable parameters: 85700356

# %%
trainer = Trainer(
    model=vit,
    device=device,
    optimizer=optimizer,
    criterion=criterion
)
# Out:
# TensorBoard logs will be saved to: runs/20260206_142429

# %%
result = trainer.fit(
    trainloader=train_loader,
    valloader=val_loader,
    epochs=epochs,
    model_name="vit_exp2",
    patience=patience,
    delta=delta
)
# Out:
# Epoch 1/100 - Training
# [========================================] 137/137 | Loss: 1.370 | Accuracy: 55.50%
# [========================================] 30/30 | Loss: 1.361 | Accuracy: 62.67%
#
# --> NEW RECORD: Best model saved (Val loss: 1.3607)
#
# Train Loss: 1.3703, Train Acc: 55.50%
# Validation Loss: 1.3607, Validation Acc: 62.67%
#
# Epoch 2/100 - Training
# [========================================] 137/137 | Loss: 1.353 | Accuracy: 61.41%
# [========================================] 30/30 | Loss: 1.342 | Accuracy: 63.85%
#
# --> NEW RECORD: Best model saved (Val loss: 1.3424)
#
# Train Loss: 1.3531, Train Acc: 61.41%
# Validation Loss: 1.3424, Validation Acc: 63.85%
#
# Epoch 3/100 - Training
# [========================================] 137/137 | Loss: 1.336 | Accuracy: 62.16%
# [========================================] 30/30 | Loss: 1.325 | Accuracy: 65.56%
#
# --> NEW RECORD: Best model saved (Val loss: 1.3245)
#
# Train Loss: 1.3360, Train Acc: 62.16%
# Validation Loss: 1.3245, Validation Acc: 65.56%
#
# Epoch 4/100 - Training
# [========================================] 137/137 | Loss: 1.320 | Accuracy: 62.98%
# [========================================] 30/30 | Loss: 1.306 | Accuracy: 66.58%
#
# --> NEW RECORD: Best model saved (Val loss: 1.3063)
#
# Train Loss: 1.3197, Train Acc: 62.98%
# Validation Loss: 1.3063, Validation Acc: 66.58%
#
# Epoch 5/100 - Training
# [========================================] 137/137 | Loss: 1.302 | Accuracy: 64.19%
# [========================================] 30/30 | Loss: 1.288 | Accuracy: 66.95%
#
# --> NEW RECORD: Best model saved (Val loss: 1.2877)
#
# Train Loss: 1.3017, Train Acc: 64.19%
# Validation Loss: 1.2877, Validation Acc: 66.95%
#
# Epoch 6/100 - Training
# [========================================] 137/137 | Loss: 1.284 | Accuracy: 64.82%
# [========================================] 30/30 | Loss: 1.272 | Accuracy: 66.68%
#
# --> NEW RECORD: Best model saved (Val loss: 1.2715)
#
# Train Loss: 1.2837, Train Acc: 64.82%
# Validation Loss: 1.2715, Validation Acc: 66.68%
#
# Epoch 7/100 - Training
# [========================================] 137/137 | Loss: 1.265 | Accuracy: 65.54%
# [========================================] 30/30 | Loss: 1.254 | Accuracy: 67.06%
#
# --> NEW RECORD: Best model saved (Val loss: 1.2535)
#
# Train Loss: 1.2653, Train Acc: 65.54%
# Validation Loss: 1.2535, Validation Acc: 67.06%
#
# Epoch 8/100 - Training
# [========================================] 137/137 | Loss: 1.248 | Accuracy: 65.78%
# [========================================] 30/30 | Loss: 1.235 | Accuracy: 67.60%
#
# --> NEW RECORD: Best model saved (Val loss: 1.2351)
#
# Train Loss: 1.2482, Train Acc: 65.78%
# Validation Loss: 1.2351, Validation Acc: 67.60%
#
# Epoch 9/100 - Training
# [========================================] 137/137 | Loss: 1.231 | Accuracy: 65.97%
# [========================================] 30/30 | Loss: 1.217 | Accuracy: 67.86%
#
# --> NEW RECORD: Best model saved (Val loss: 1.2168)
#
# Train Loss: 1.2314, Train Acc: 65.97%
# Validation Loss: 1.2168, Validation Acc: 67.86%
#
# Epoch 10/100 - Training
# [========================================] 137/137 | Loss: 1.214 | Accuracy: 66.25%
# [========================================] 30/30 | Loss: 1.200 | Accuracy: 68.02%
#
# --> NEW RECORD: Best model saved (Val loss: 1.2000)
#
# Train Loss: 1.2138, Train Acc: 66.25%
# Validation Loss: 1.2000, Validation Acc: 68.02%
#
# Epoch 11/100 - Training
# [========================================] 137/137 | Loss: 1.199 | Accuracy: 66.10%
# [========================================] 30/30 | Loss: 1.184 | Accuracy: 68.08%
#
# --> NEW RECORD: Best model saved (Val loss: 1.1838)
#
# Train Loss: 1.1990, Train Acc: 66.10%
# Validation Loss: 1.1838, Validation Acc: 68.08%
#
# Epoch 12/100 - Training
# [========================================] 137/137 | Loss: 1.184 | Accuracy: 66.40%
# [========================================] 30/30 | Loss: 1.170 | Accuracy: 68.18%
#
# --> NEW RECORD: Best model saved (Val loss: 1.1700)
#
# Train Loss: 1.1838, Train Acc: 66.40%
# Validation Loss: 1.1700, Validation Acc: 68.18%
#
# Epoch 13/100 - Training
# [========================================] 137/137 | Loss: 1.169 | Accuracy: 66.54%
# [========================================] 30/30 | Loss: 1.153 | Accuracy: 68.40%
#
# --> NEW RECORD: Best model saved (Val loss: 1.1529)
#
# Train Loss: 1.1691, Train Acc: 66.54%
# Validation Loss: 1.1529, Validation Acc: 68.40%
#
# Epoch 14/100 - Training
# [========================================] 137/137 | Loss: 1.154 | Accuracy: 66.76%
# [========================================] 30/30 | Loss: 1.140 | Accuracy: 68.40%
#
# --> NEW RECORD: Best model saved (Val loss: 1.1396)
#
# Train Loss: 1.1540, Train Acc: 66.76%
# Validation Loss: 1.1396, Validation Acc: 68.40%
#
# Epoch 15/100 - Training
# [========================================] 137/137 | Loss: 1.141 | Accuracy: 66.67%
# [========================================] 30/30 | Loss: 1.128 | Accuracy: 68.34%
#
# --> NEW RECORD: Best model saved (Val loss: 1.1277)
#
# Train Loss: 1.1409, Train Acc: 66.67%
# Validation Loss: 1.1277, Validation Acc: 68.34%
#
# Epoch 16/100 - Training
# [========================================] 137/137 | Loss: 1.126 | Accuracy: 66.98%
# [========================================] 30/30 | Loss: 1.113 | Accuracy: 68.51%
#
# --> NEW RECORD: Best model saved (Val loss: 1.1132)
#
# Train Loss: 1.1260, Train Acc: 66.98%
# Validation Loss: 1.1132, Validation Acc: 68.51%
#
# Epoch 17/100 - Training
# [========================================] 137/137 | Loss: 1.116 | Accuracy: 66.99%
# [========================================] 30/30 | Loss: 1.103 | Accuracy: 68.40%
#
# --> NEW RECORD: Best model saved (Val loss: 1.1028)
#
# Train Loss: 1.1158, Train Acc: 66.99%
# Validation Loss: 1.1028, Validation Acc: 68.40%
#
# Epoch 18/100 - Training
# [========================================] 137/137 | Loss: 1.101 | Accuracy: 67.08%
# [========================================] 30/30 | Loss: 1.087 | Accuracy: 68.77%
#
# --> NEW RECORD: Best model saved (Val loss: 1.0875)
#
# Train Loss: 1.1015, Train Acc: 67.08%
# Validation Loss: 1.0875, Validation Acc: 68.77%
#
# Epoch 19/100 - Training
# [========================================] 137/137 | Loss: 1.093 | Accuracy: 66.77%
# [========================================] 30/30 | Loss: 1.076 | Accuracy: 68.34%
#
# --> NEW RECORD: Best model saved (Val loss: 1.0759)
#
# Train Loss: 1.0925, Train Acc: 66.77%
# Validation Loss: 1.0759, Validation Acc: 68.34%
#
# Epoch 20/100 - Training
# [========================================] 137/137 | Loss: 1.081 | Accuracy: 66.83%
# [========================================] 30/30 | Loss: 1.068 | Accuracy: 68.40%
#
# --> NEW RECORD: Best model saved (Val loss: 1.0685)
#
# Train Loss: 1.0806, Train Acc: 66.83%
# Validation Loss: 1.0685, Validation Acc: 68.40%
#
# Epoch 21/100 - Training
# [========================================] 137/137 | Loss: 1.069 | Accuracy: 67.17%
# [========================================] 30/30 | Loss: 1.059 | Accuracy: 68.45%
#
# --> NEW RECORD: Best model saved (Val loss: 1.0586)
#
# Train Loss: 1.0688, Train Acc: 67.17%
# Validation Loss: 1.0586, Validation Acc: 68.45%
#
# Epoch 22/100 - Training
# [========================================] 137/137 | Loss: 1.061 | Accuracy: 67.02%
# [========================================] 30/30 | Loss: 1.048 | Accuracy: 68.51%
#
# --> NEW RECORD: Best model saved (Val loss: 1.0484)
#
# Train Loss: 1.0609, Train Acc: 67.02%
# Validation Loss: 1.0484, Validation Acc: 68.51%
#
# Epoch 23/100 - Training
# [========================================] 137/137 | Loss: 1.046 | Accuracy: 67.31%
# [========================================] 30/30 | Loss: 1.039 | Accuracy: 68.40%
#
# --> NEW RECORD: Best model saved (Val loss: 1.0389)
#
# Train Loss: 1.0463, Train Acc: 67.31%
# Validation Loss: 1.0389, Validation Acc: 68.40%
#
# Epoch 24/100 - Training
# [========================================] 137/137 | Loss: 1.040 | Accuracy: 67.49%
# [========================================] 30/30 | Loss: 1.032 | Accuracy: 68.13%
#
# --> NEW RECORD: Best model saved (Val loss: 1.0319)
#
# Train Loss: 1.0399, Train Acc: 67.49%
# Validation Loss: 1.0319, Validation Acc: 68.13%
#
# Epoch 25/100 - Training
# [========================================] 137/137 | Loss: 1.029 | Accuracy: 67.37%
# [========================================] 30/30 | Loss: 1.014 | Accuracy: 68.99%
#
# --> NEW RECORD: Best model saved (Val loss: 1.0141)
#
# Train Loss: 1.0290, Train Acc: 67.37%
# Validation Loss: 1.0141, Validation Acc: 68.99%
#
# Epoch 26/100 - Training
# [========================================] 137/137 | Loss: 1.018 | Accuracy: 67.49%
# [========================================] 30/30 | Loss: 1.004 | Accuracy: 69.15%
#
# --> NEW RECORD: Best model saved (Val loss: 1.0038)
#
# Train Loss: 1.0181, Train Acc: 67.49%
# Validation Loss: 1.0038, Validation Acc: 69.15%
#
# Epoch 27/100 - Training
# [========================================] 137/137 | Loss: 1.011 | Accuracy: 67.72%
# [========================================] 30/30 | Loss: 0.996 | Accuracy: 69.20%
#
# --> NEW RECORD: Best model saved (Val loss: 0.9963)
#
# Train Loss: 1.0111, Train Acc: 67.72%
# Validation Loss: 0.9963, Validation Acc: 69.20%
#
# Epoch 28/100 - Training
# [========================================] 137/137 | Loss: 1.000 | Accuracy: 67.86%
# [========================================] 30/30 | Loss: 0.987 | Accuracy: 68.99%
#
# --> NEW RECORD: Best model saved (Val loss: 0.9873)
#
# Train Loss: 0.9997, Train Acc: 67.86%
# Validation Loss: 0.9873, Validation Acc: 68.99%
#
# Epoch 29/100 - Training
# [========================================] 137/137 | Loss: 0.991 | Accuracy: 68.08%
# [========================================] 30/30 | Loss: 0.983 | Accuracy: 68.99%
#
# --> NEW RECORD: Best model saved (Val loss: 0.9834)
#
# Train Loss: 0.9906, Train Acc: 68.08%
# Validation Loss: 0.9834, Validation Acc: 68.99%
#
# Epoch 30/100 - Training
# [========================================] 137/137 | Loss: 0.982 | Accuracy: 68.06%
# [========================================] 30/30 | Loss: 0.972 | Accuracy: 68.83%
#
# --> NEW RECORD: Best model saved (Val loss: 0.9718)
#
# Train Loss: 0.9819, Train Acc: 68.06%
# Validation Loss: 0.9718, Validation Acc: 68.83%
#
# Epoch 31/100 - Training
# [========================================] 137/137 | Loss: 0.982 | Accuracy: 67.85%
# [========================================] 30/30 | Loss: 0.971 | Accuracy: 68.45%
#
# --> NEW RECORD: Best model saved (Val loss: 0.9713)
#
# Train Loss: 0.9816, Train Acc: 67.85%
# Validation Loss: 0.9713, Validation Acc: 68.45%
#
# Epoch 32/100 - Training
# [========================================] 137/137 | Loss: 0.971 | Accuracy: 67.81%
# [========================================] 30/30 | Loss: 0.959 | Accuracy: 69.47%
#
# --> NEW RECORD: Best model saved (Val loss: 0.9585)
#
# Train Loss: 0.9711, Train Acc: 67.81%
# Validation Loss: 0.9585, Validation Acc: 69.47%
#
# Epoch 33/100 - Training
# [========================================] 137/137 | Loss: 0.963 | Accuracy: 68.19%
# [========================================] 30/30 | Loss: 0.948 | Accuracy: 69.36%
#
# --> NEW RECORD: Best model saved (Val loss: 0.9482)
#
# Train Loss: 0.9627, Train Acc: 68.19%
# Validation Loss: 0.9482, Validation Acc: 69.36%
#
# Epoch 34/100 - Training
# [========================================] 137/137 | Loss: 0.956 | Accuracy: 68.00%
# [========================================] 30/30 | Loss: 0.951 | Accuracy: 68.45%
#
# Train Loss: 0.9561, Train Acc: 68.00%
# Validation Loss: 0.9512, Validation Acc: 68.45%
#
# Epoch 35/100 - Training
# [========================================] 137/137 | Loss: 0.947 | Accuracy: 68.32%
# [========================================] 30/30 | Loss: 0.937 | Accuracy: 69.20%
#
# --> NEW RECORD: Best model saved (Val loss: 0.9374)
#
# Train Loss: 0.9467, Train Acc: 68.32%
# Validation Loss: 0.9374, Validation Acc: 69.20%
#
# Epoch 36/100 - Training
# [========================================] 137/137 | Loss: 0.939 | Accuracy: 68.42%
# [========================================] 30/30 | Loss: 0.936 | Accuracy: 68.72%
#
# --> NEW RECORD: Best model saved (Val loss: 0.9358)
#
# Train Loss: 0.9391, Train Acc: 68.42%
# Validation Loss: 0.9358, Validation Acc: 68.72%
#
# Epoch 37/100 - Training
# [========================================] 137/137 | Loss: 0.940 | Accuracy: 68.12%
# [========================================] 30/30 | Loss: 0.927 | Accuracy: 69.15%
#
# --> NEW RECORD: Best model saved (Val loss: 0.9265)
#
# Train Loss: 0.9400, Train Acc: 68.12%
# Validation Loss: 0.9265, Validation Acc: 69.15%
#
# Epoch 38/100 - Training
# [========================================] 137/137 | Loss: 0.930 | Accuracy: 68.35%
# [========================================] 30/30 | Loss: 0.920 | Accuracy: 68.88%
#
# --> NEW RECORD: Best model saved (Val loss: 0.9205)
#
# Train Loss: 0.9299, Train Acc: 68.35%
# Validation Loss: 0.9205, Validation Acc: 68.88%
#
# Epoch 39/100 - Training
# [========================================] 137/137 | Loss: 0.922 | Accuracy: 68.06%
# [========================================] 30/30 | Loss: 0.914 | Accuracy: 69.42%
#
# --> NEW RECORD: Best model saved (Val loss: 0.9141)
#
# Train Loss: 0.9220, Train Acc: 68.06%
# Validation Loss: 0.9141, Validation Acc: 69.42%
#
# Epoch 40/100 - Training
# [========================================] 137/137 | Loss: 0.917 | Accuracy: 68.62%
# [========================================] 30/30 | Loss: 0.914 | Accuracy: 68.51%
#
# Train Loss: 0.9172, Train Acc: 68.62%
# Validation Loss: 0.9144, Validation Acc: 68.51%
#
# Epoch 41/100 - Training
# [========================================] 137/137 | Loss: 0.908 | Accuracy: 68.51%
# [========================================] 30/30 | Loss: 0.903 | Accuracy: 69.79%
#
# --> NEW RECORD: Best model saved (Val loss: 0.9025)
#
# Train Loss: 0.9084, Train Acc: 68.51%
# Validation Loss: 0.9025, Validation Acc: 69.79%
#
# Epoch 42/100 - Training
# [========================================] 137/137 | Loss: 0.907 | Accuracy: 68.34%
# [========================================] 30/30 | Loss: 0.908 | Accuracy: 68.45%
#
# Train Loss: 0.9074, Train Acc: 68.34%
# Validation Loss: 0.9082, Validation Acc: 68.45%
#
# Epoch 43/100 - Training
# [========================================] 137/137 | Loss: 0.900 | Accuracy: 68.84%
# [========================================] 30/30 | Loss: 0.893 | Accuracy: 69.63%
#
# --> NEW RECORD: Best model saved (Val loss: 0.8927)
#
# Train Loss: 0.8999, Train Acc: 68.84%
# Validation Loss: 0.8927, Validation Acc: 69.63%
#
# Epoch 44/100 - Training
# [========================================] 137/137 | Loss: 0.899 | Accuracy: 68.09%
# [========================================] 30/30 | Loss: 0.883 | Accuracy: 70.06%
#
# --> NEW RECORD: Best model saved (Val loss: 0.8828)
#
# Train Loss: 0.8988, Train Acc: 68.09%
# Validation Loss: 0.8828, Validation Acc: 70.06%
#
# Epoch 45/100 - Training
# [========================================] 137/137 | Loss: 0.894 | Accuracy: 68.60%
# [========================================] 30/30 | Loss: 0.892 | Accuracy: 68.29%
#
# Train Loss: 0.8936, Train Acc: 68.60%
# Validation Loss: 0.8918, Validation Acc: 68.29%
#
# Epoch 46/100 - Training
# [========================================] 137/137 | Loss: 0.889 | Accuracy: 68.86%
# [========================================] 30/30 | Loss: 0.880 | Accuracy: 69.52%
#
# --> NEW RECORD: Best model saved (Val loss: 0.8795)
#
# Train Loss: 0.8892, Train Acc: 68.86%
# Validation Loss: 0.8795, Validation Acc: 69.52%
#
# Epoch 47/100 - Training
# [========================================] 137/137 | Loss: 0.884 | Accuracy: 68.78%
# [========================================] 30/30 | Loss: 0.874 | Accuracy: 69.52%
#
# --> NEW RECORD: Best model saved (Val loss: 0.8744)
#
# Train Loss: 0.8844, Train Acc: 68.78%
# Validation Loss: 0.8744, Validation Acc: 69.52%
#
# Epoch 48/100 - Training
# [========================================] 137/137 | Loss: 0.881 | Accuracy: 68.68%
# [========================================] 30/30 | Loss: 0.870 | Accuracy: 69.52%
#
# --> NEW RECORD: Best model saved (Val loss: 0.8696)
#
# Train Loss: 0.8814, Train Acc: 68.68%
# Validation Loss: 0.8696, Validation Acc: 69.52%
#
# Epoch 49/100 - Training
# [========================================] 137/137 | Loss: 0.873 | Accuracy: 69.04%
# [========================================] 30/30 | Loss: 0.908 | Accuracy: 68.34%
#
# Train Loss: 0.8728, Train Acc: 69.04%
# Validation Loss: 0.9078, Validation Acc: 68.34%
#
# Epoch 50/100 - Training
# [========================================] 137/137 | Loss: 0.873 | Accuracy: 68.85%
# [========================================] 30/30 | Loss: 0.858 | Accuracy: 69.52%
#
# --> NEW RECORD: Best model saved (Val loss: 0.8579)
#
# Train Loss: 0.8726, Train Acc: 68.85%
# Validation Loss: 0.8579, Validation Acc: 69.52%
#
# Epoch 51/100 - Training
# [========================================] 137/137 | Loss: 0.869 | Accuracy: 68.90%
# [========================================] 30/30 | Loss: 0.856 | Accuracy: 70.76%
#
# --> NEW RECORD: Best model saved (Val loss: 0.8556)
#
# Train Loss: 0.8687, Train Acc: 68.90%
# Validation Loss: 0.8556, Validation Acc: 70.76%
#
# Epoch 52/100 - Training
# [========================================] 137/137 | Loss: 0.865 | Accuracy: 69.10%
# [========================================] 30/30 | Loss: 0.856 | Accuracy: 70.06%
#
# Train Loss: 0.8650, Train Acc: 69.10%
# Validation Loss: 0.8563, Validation Acc: 70.06%
#
# Epoch 53/100 - Training
# [========================================] 137/137 | Loss: 0.857 | Accuracy: 69.26%
# [========================================] 30/30 | Loss: 0.848 | Accuracy: 70.59%
#
# --> NEW RECORD: Best model saved (Val loss: 0.8481)
#
# Train Loss: 0.8572, Train Acc: 69.26%
# Validation Loss: 0.8481, Validation Acc: 70.59%
#
# Epoch 54/100 - Training
# [========================================] 137/137 | Loss: 0.857 | Accuracy: 69.03%
# [========================================] 30/30 | Loss: 0.851 | Accuracy: 69.74%
#
# Train Loss: 0.8575, Train Acc: 69.03%
# Validation Loss: 0.8507, Validation Acc: 69.74%
#
# Epoch 55/100 - Training
# [========================================] 137/137 | Loss: 0.857 | Accuracy: 69.07%
# [========================================] 30/30 | Loss: 0.839 | Accuracy: 70.76%
#
# --> NEW RECORD: Best model saved (Val loss: 0.8394)
#
# Train Loss: 0.8570, Train Acc: 69.07%
# Validation Loss: 0.8394, Validation Acc: 70.76%
#
# Epoch 56/100 - Training
# [========================================] 137/137 | Loss: 0.854 | Accuracy: 69.07%
# [========================================] 30/30 | Loss: 0.845 | Accuracy: 69.58%
#
# Train Loss: 0.8539, Train Acc: 69.07%
# Validation Loss: 0.8453, Validation Acc: 69.58%
#
# Epoch 57/100 - Training
# [========================================] 137/137 | Loss: 0.849 | Accuracy: 68.72%
# [========================================] 30/30 | Loss: 0.846 | Accuracy: 68.99%
#
# Train Loss: 0.8490, Train Acc: 68.72%
# Validation Loss: 0.8458, Validation Acc: 68.99%
#
# Epoch 58/100 - Training
# [========================================] 137/137 | Loss: 0.843 | Accuracy: 69.13%
# [========================================] 30/30 | Loss: 0.833 | Accuracy: 70.43%
#
# --> NEW RECORD: Best model saved (Val loss: 0.8325)
#
# Train Loss: 0.8431, Train Acc: 69.13%
# Validation Loss: 0.8325, Validation Acc: 70.43%
#
# Epoch 59/100 - Training
# [========================================] 137/137 | Loss: 0.839 | Accuracy: 69.19%
# [========================================] 30/30 | Loss: 0.832 | Accuracy: 70.11%
#
# --> NEW RECORD: Best model saved (Val loss: 0.8323)
#
# Train Loss: 0.8393, Train Acc: 69.19%
# Validation Loss: 0.8323, Validation Acc: 70.11%
#
# Epoch 60/100 - Training
# [========================================] 137/137 | Loss: 0.838 | Accuracy: 69.46%
# [========================================] 30/30 | Loss: 0.831 | Accuracy: 70.06%
#
# --> NEW RECORD: Best model saved (Val loss: 0.8315)
#
# Train Loss: 0.8379, Train Acc: 69.46%
# Validation Loss: 0.8315, Validation Acc: 70.06%
#
# Epoch 61/100 - Training
# [========================================] 137/137 | Loss: 0.832 | Accuracy: 69.61%
# [========================================] 30/30 | Loss: 0.822 | Accuracy: 70.38%
#
# --> NEW RECORD: Best model saved (Val loss: 0.8221)
#
# Train Loss: 0.8320, Train Acc: 69.61%
# Validation Loss: 0.8221, Validation Acc: 70.38%
#
# Epoch 62/100 - Training
# [========================================] 137/137 | Loss: 0.834 | Accuracy: 69.34%
# [========================================] 30/30 | Loss: 0.817 | Accuracy: 70.65%
#
# --> NEW RECORD: Best model saved (Val loss: 0.8169)
#
# Train Loss: 0.8338, Train Acc: 69.34%
# Validation Loss: 0.8169, Validation Acc: 70.65%
#
# Epoch 63/100 - Training
# [========================================] 137/137 | Loss: 0.832 | Accuracy: 69.09%
# [========================================] 30/30 | Loss: 0.819 | Accuracy: 70.54%
#
# Train Loss: 0.8321, Train Acc: 69.09%
# Validation Loss: 0.8190, Validation Acc: 70.54%
#
# Epoch 64/100 - Training
# [========================================] 137/137 | Loss: 0.828 | Accuracy: 69.51%
# [========================================] 30/30 | Loss: 0.819 | Accuracy: 70.11%
#
# Train Loss: 0.8280, Train Acc: 69.51%
# Validation Loss: 0.8192, Validation Acc: 70.11%
#
# Epoch 65/100 - Training
# [========================================] 137/137 | Loss: 0.825 | Accuracy: 69.63%
# [========================================] 30/30 | Loss: 0.825 | Accuracy: 69.68%
#
# Train Loss: 0.8253, Train Acc: 69.63%
# Validation Loss: 0.8251, Validation Acc: 69.68%
#
# Epoch 66/100 - Training
# [========================================] 137/137 | Loss: 0.824 | Accuracy: 69.56%
# [========================================] 30/30 | Loss: 0.808 | Accuracy: 70.54%
#
# --> NEW RECORD: Best model saved (Val loss: 0.8085)
#
# Train Loss: 0.8245, Train Acc: 69.56%
# Validation Loss: 0.8085, Validation Acc: 70.54%
#
# Epoch 67/100 - Training
# [========================================] 137/137 | Loss: 0.817 | Accuracy: 69.47%
# [========================================] 30/30 | Loss: 0.819 | Accuracy: 69.90%
#
# Train Loss: 0.8166, Train Acc: 69.47%
# Validation Loss: 0.8189, Validation Acc: 69.90%
#
# Epoch 68/100 - Training
# [========================================] 137/137 | Loss: 0.813 | Accuracy: 69.66%
# [========================================] 30/30 | Loss: 0.818 | Accuracy: 69.90%
#
# Train Loss: 0.8134, Train Acc: 69.66%
# Validation Loss: 0.8177, Validation Acc: 69.90%
#
# Epoch 69/100 - Training
# [========================================] 137/137 | Loss: 0.809 | Accuracy: 69.78%
# [========================================] 30/30 | Loss: 0.800 | Accuracy: 70.49%
#
# --> NEW RECORD: Best model saved (Val loss: 0.7996)
#
# Train Loss: 0.8088, Train Acc: 69.78%
# Validation Loss: 0.7996, Validation Acc: 70.49%
#
# Epoch 70/100 - Training
# [========================================] 137/137 | Loss: 0.812 | Accuracy: 69.66%
# [========================================] 30/30 | Loss: 0.817 | Accuracy: 69.74%
#
# Train Loss: 0.8117, Train Acc: 69.66%
# Validation Loss: 0.8168, Validation Acc: 69.74%
#
# Epoch 71/100 - Training
# [========================================] 137/137 | Loss: 0.807 | Accuracy: 69.90%
# [========================================] 30/30 | Loss: 0.802 | Accuracy: 70.65%
#
# Train Loss: 0.8067, Train Acc: 69.90%
# Validation Loss: 0.8021, Validation Acc: 70.65%
#
# Epoch 72/100 - Training
# [========================================] 137/137 | Loss: 0.811 | Accuracy: 69.79%
# [========================================] 30/30 | Loss: 0.794 | Accuracy: 70.54%
#
# --> NEW RECORD: Best model saved (Val loss: 0.7936)
#
# Train Loss: 0.8110, Train Acc: 69.79%
# Validation Loss: 0.7936, Validation Acc: 70.54%
#
# Epoch 73/100 - Training
# [========================================] 137/137 | Loss: 0.802 | Accuracy: 70.08%
# [========================================] 30/30 | Loss: 0.792 | Accuracy: 70.38%
#
# --> NEW RECORD: Best model saved (Val loss: 0.7922)
#
# Train Loss: 0.8025, Train Acc: 70.08%
# Validation Loss: 0.7922, Validation Acc: 70.38%
#
# Epoch 74/100 - Training
# [========================================] 137/137 | Loss: 0.801 | Accuracy: 70.08%
# [========================================] 30/30 | Loss: 0.789 | Accuracy: 70.76%
#
# --> NEW RECORD: Best model saved (Val loss: 0.7889)
#
# Train Loss: 0.8008, Train Acc: 70.08%
# Validation Loss: 0.7889, Validation Acc: 70.76%
#
# Epoch 75/100 - Training
# [========================================] 137/137 | Loss: 0.800 | Accuracy: 69.96%
# [========================================] 30/30 | Loss: 0.805 | Accuracy: 70.65%
#
# Train Loss: 0.8002, Train Acc: 69.96%
# Validation Loss: 0.8053, Validation Acc: 70.65%
#
# Epoch 76/100 - Training
# [========================================] 137/137 | Loss: 0.793 | Accuracy: 70.39%
# [========================================] 30/30 | Loss: 0.797 | Accuracy: 71.13%
#
# Train Loss: 0.7925, Train Acc: 70.39%
# Validation Loss: 0.7970, Validation Acc: 71.13%
#
# Epoch 77/100 - Training
# [========================================] 137/137 | Loss: 0.795 | Accuracy: 70.12%
# [========================================] 30/30 | Loss: 0.782 | Accuracy: 71.02%
#
# --> NEW RECORD: Best model saved (Val loss: 0.7819)
#
# Train Loss: 0.7945, Train Acc: 70.12%
# Validation Loss: 0.7819, Validation Acc: 71.02%
#
# Epoch 78/100 - Training
# [========================================] 137/137 | Loss: 0.792 | Accuracy: 70.35%
# [========================================] 30/30 | Loss: 0.788 | Accuracy: 71.56%
#
# Train Loss: 0.7922, Train Acc: 70.35%
# Validation Loss: 0.7875, Validation Acc: 71.56%
#
# Epoch 79/100 - Training
# [========================================] 137/137 | Loss: 0.790 | Accuracy: 70.34%
# [========================================] 30/30 | Loss: 0.776 | Accuracy: 71.34%
#
# --> NEW RECORD: Best model saved (Val loss: 0.7757)
#
# Train Loss: 0.7899, Train Acc: 70.34%
# Validation Loss: 0.7757, Validation Acc: 71.34%
#
# Epoch 80/100 - Training
# [========================================] 137/137 | Loss: 0.789 | Accuracy: 70.47%
# [========================================] 30/30 | Loss: 0.780 | Accuracy: 71.72%
#
# Train Loss: 0.7889, Train Acc: 70.47%
# Validation Loss: 0.7795, Validation Acc: 71.72%
#
# Epoch 81/100 - Training
# [========================================] 137/137 | Loss: 0.785 | Accuracy: 70.71%
# [========================================] 30/30 | Loss: 0.778 | Accuracy: 71.99%
#
# Train Loss: 0.7852, Train Acc: 70.71%
# Validation Loss: 0.7778, Validation Acc: 71.99%
#
# Epoch 82/100 - Training
# [========================================] 137/137 | Loss: 0.789 | Accuracy: 70.55%
# [========================================] 30/30 | Loss: 0.774 | Accuracy: 71.40%
#
# --> NEW RECORD: Best model saved (Val loss: 0.7745)
#
# Train Loss: 0.7894, Train Acc: 70.55%
# Validation Loss: 0.7745, Validation Acc: 71.40%
#
# Epoch 83/100 - Training
# [========================================] 137/137 | Loss: 0.779 | Accuracy: 71.01%
# [========================================] 30/30 | Loss: 0.766 | Accuracy: 72.20%
#
# --> NEW RECORD: Best model saved (Val loss: 0.7657)
#
# Train Loss: 0.7790, Train Acc: 71.01%
# Validation Loss: 0.7657, Validation Acc: 72.20%
#
# Epoch 84/100 - Training
# [========================================] 137/137 | Loss: 0.780 | Accuracy: 70.83%
# [========================================] 30/30 | Loss: 0.771 | Accuracy: 71.45%
#
# Train Loss: 0.7798, Train Acc: 70.83%
# Validation Loss: 0.7713, Validation Acc: 71.45%
#
# Epoch 85/100 - Training
# [========================================] 137/137 | Loss: 0.782 | Accuracy: 71.06%
# [========================================] 30/30 | Loss: 0.768 | Accuracy: 71.40%
#
# Train Loss: 0.7818, Train Acc: 71.06%
# Validation Loss: 0.7679, Validation Acc: 71.40%
#
# Epoch 86/100 - Training
# [========================================] 137/137 | Loss: 0.774 | Accuracy: 71.05%
# [========================================] 30/30 | Loss: 0.762 | Accuracy: 71.77%
#
# --> NEW RECORD: Best model saved (Val loss: 0.7616)
#
# Train Loss: 0.7735, Train Acc: 71.05%
# Validation Loss: 0.7616, Validation Acc: 71.77%
#
# Epoch 87/100 - Training
# [========================================] 137/137 | Loss: 0.775 | Accuracy: 71.05%
# [========================================] 30/30 | Loss: 0.763 | Accuracy: 71.67%
#
# Train Loss: 0.7753, Train Acc: 71.05%
# Validation Loss: 0.7631, Validation Acc: 71.67%
#
# Epoch 88/100 - Training
# [========================================] 137/137 | Loss: 0.768 | Accuracy: 71.49%
# [========================================] 30/30 | Loss: 0.760 | Accuracy: 72.63%
#
# --> NEW RECORD: Best model saved (Val loss: 0.7598)
#
# Train Loss: 0.7683, Train Acc: 71.49%
# Validation Loss: 0.7598, Validation Acc: 72.63%
#
# Epoch 89/100 - Training
# [========================================] 137/137 | Loss: 0.766 | Accuracy: 71.80%
# [========================================] 30/30 | Loss: 0.759 | Accuracy: 72.84%
#
# --> NEW RECORD: Best model saved (Val loss: 0.7592)
#
# Train Loss: 0.7663, Train Acc: 71.80%
# Validation Loss: 0.7592, Validation Acc: 72.84%
#
# Epoch 90/100 - Training
# [========================================] 137/137 | Loss: 0.766 | Accuracy: 71.61%
# [========================================] 30/30 | Loss: 0.754 | Accuracy: 72.63%
#
# --> NEW RECORD: Best model saved (Val loss: 0.7540)
#
# Train Loss: 0.7656, Train Acc: 71.61%
# Validation Loss: 0.7540, Validation Acc: 72.63%
#
# Epoch 91/100 - Training
# [========================================] 137/137 | Loss: 0.766 | Accuracy: 71.65%
# [========================================] 30/30 | Loss: 0.778 | Accuracy: 72.63%
#
# Train Loss: 0.7662, Train Acc: 71.65%
# Validation Loss: 0.7784, Validation Acc: 72.63%
#
# Epoch 92/100 - Training
# [========================================] 137/137 | Loss: 0.771 | Accuracy: 71.40%
# [========================================] 30/30 | Loss: 0.749 | Accuracy: 72.36%
#
# --> NEW RECORD: Best model saved (Val loss: 0.7486)
#
# Train Loss: 0.7711, Train Acc: 71.40%
# Validation Loss: 0.7486, Validation Acc: 72.36%
#
# Epoch 93/100 - Training
# [========================================] 137/137 | Loss: 0.760 | Accuracy: 72.06%
# [========================================] 30/30 | Loss: 0.747 | Accuracy: 72.42%
#
# --> NEW RECORD: Best model saved (Val loss: 0.7466)
#
# Train Loss: 0.7599, Train Acc: 72.06%
# Validation Loss: 0.7466, Validation Acc: 72.42%
#
# Epoch 94/100 - Training
# [========================================] 137/137 | Loss: 0.758 | Accuracy: 72.27%
# [========================================] 30/30 | Loss: 0.748 | Accuracy: 72.58%
#
# Train Loss: 0.7585, Train Acc: 72.27%
# Validation Loss: 0.7484, Validation Acc: 72.58%
#
# Epoch 95/100 - Training
# [========================================] 137/137 | Loss: 0.753 | Accuracy: 72.46%
# [========================================] 30/30 | Loss: 0.754 | Accuracy: 73.49%
#
# Train Loss: 0.7533, Train Acc: 72.46%
# Validation Loss: 0.7542, Validation Acc: 73.49%
#
# Epoch 96/100 - Training
# [========================================] 137/137 | Loss: 0.755 | Accuracy: 72.51%
# [========================================] 30/30 | Loss: 0.737 | Accuracy: 72.90%
#
# --> NEW RECORD: Best model saved (Val loss: 0.7373)
#
# Train Loss: 0.7550, Train Acc: 72.51%
# Validation Loss: 0.7373, Validation Acc: 72.90%
#
# Epoch 97/100 - Training
# [========================================] 137/137 | Loss: 0.756 | Accuracy: 72.02%
# [========================================] 30/30 | Loss: 0.747 | Accuracy: 73.38%
#
# Train Loss: 0.7560, Train Acc: 72.02%
# Validation Loss: 0.7465, Validation Acc: 73.38%
#
# Epoch 98/100 - Training
# [========================================] 137/137 | Loss: 0.754 | Accuracy: 72.47%
# [========================================] 30/30 | Loss: 0.740 | Accuracy: 72.31%
#
# Train Loss: 0.7539, Train Acc: 72.47%
# Validation Loss: 0.7404, Validation Acc: 72.31%
#
# Epoch 99/100 - Training
# [========================================] 137/137 | Loss: 0.754 | Accuracy: 72.70%
# [========================================] 30/30 | Loss: 0.741 | Accuracy: 74.18%
#
# Train Loss: 0.7540, Train Acc: 72.70%
# Validation Loss: 0.7412, Validation Acc: 74.18%
#
# Epoch 100/100 - Training
# [========================================] 137/137 | Loss: 0.744 | Accuracy: 73.08%
# [========================================] 30/30 | Loss: 0.732 | Accuracy: 73.38%
#
# --> NEW RECORD: Best model saved (Val loss: 0.7317)
#
# Train Loss: 0.7441, Train Acc: 73.08%
# Validation Loss: 0.7317, Validation Acc: 73.38%
#
# Training complete in 200m 26s

# %%
plot_result(result)

# %%
results = trainer.evaluate(
    testloader=test_loader,
    model_path="/kaggle/working/vit_exp2_e99_20260206_142712.pt"
)
# Out:
# [========================================] 30/30 | Loss: 0.738 | Accuracy: 72.04%
#
# =========================
# TEST SET RESULTS
# =========================
# Loss      : 0.7380
# Accuracy  : 0.7204
# Precision : 0.6979
# F1        : 0.6599

# %%
cm = confusion_matrix(results[0], results[1])
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Tumor', 'Normal', 'Stone', 'Cyst'])
disp.plot(cmap='Blues', xticks_rotation=45)
plt.title("Confusion Matrix - Test Set")
plt.show()
